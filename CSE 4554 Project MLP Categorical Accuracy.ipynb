# %% [markdown]
# # Install and Import Dependencies

# %% [markdown]
# Most of the project dependencies are installed and necessary modules are imported from the libraries.
#
# - <u>tensorflow</u>: for defining and training the machine learning model
# - <u>numpy</u>: for numerical operations, array handling and data manipulation and processing
# - <u>opencv-python</u>: for frame processing
# - <u>matplotlib</u>: for visualization of data and create graphs of results
# - <u>mediapipe</u>: for extraction of landmarks of hands, pose and face from frames
# - <u>sckit-learn</u>: for evaluation of model using confusion matrix, roc curve and auc
# - <u>tqdm</u>: for creating progress bars to visualize progress during data processing and training
# - <u>fasttext-wheel</u>: for encoding labels to vectors
# - <u>seaborn</u>: for plotting the confusion matrix
# - <u>threading</u>: for task parallelization during landmark extraction

# %%
pip install -q --upgrade tensorflow
# Out:
# Note: you may need to restart the kernel to use updated packages.
# DEPRECATION: Loading egg at e:\swe\python3.11.5\lib\site-packages\vboxapi-1.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330

# %%
pip install -q opencv-python numpy matplotlib mediapipe scikit-learn tqdm fasttext-wheel seaborn tensorflow
# Out:
# Note: you may need to restart the kernel to use updated packages.
# DEPRECATION: Loading egg at e:\swe\python3.11.5\lib\site-packages\vboxapi-1.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330

# %%
import cv2
import numpy as np
import gc
import os
from matplotlib import pyplot as plt
import shutil
import threading
import mediapipe as mp
import json
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tqdm import tqdm
import fasttext
import fasttext.util
from sklearn.metrics import confusion_matrix
import seaborn as sns
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from itertools import cycle
from keras.utils import to_categorical

# %% [markdown]
# # Load dataset

# %% [markdown]
# A base directory is defined which will be used throughout project to ensure the directory can be changed if required.
#
# The contents of **WLASL_v0.3.json** is stored in a variable `data` which is used for extracting labels for the video and categorizing input data into train, test and validation split.
#
# Next the `data` variable is checked to see if it has instantiated properly.
#
# **missing.txt** is opened in `` to check which videos are missing from the dataset provided to skip processing for missing videos.
#
# Afterwards the variables used for file reading are discarded and garbage collect the memory no longer in use. This is done in multiple places throughout the project to ensure efficient memory usage and prevent MemoryError.

# %%
# defining a base directory to the dataset folder
main_path = './dataset/'
# opening the json file for read
with open(main_path + 'WLASL_v0.3.json', 'r') as json_file:
    data = json.load(json_file)

# %%
# checking to see if data has loaded properly
len(data[0]['instances'])
# Out:
# 40

# %%
# opening the file in read mode
with open(main_path + 'missing.txt', 'r') as file:
    # Reads all lines from the file and stores them in a list
    missing_video_ids = [line.strip() for line in file.readlines()]

# Now, 'lines' contains an array of strings, where each element is a line from the file
print(missing_video_ids)
# Out:
# []

# %%
del file, json_file
gc.collect()
# Out:
# 4

# %% [markdown]
# # Create Labels and Features

# %% [markdown]
# The `data` is processed to extract the labels and data required for creating feature.
#
# - Each unique gesture in `data` is iterated.
# - For each word, it is checked if the video listed is missing based on the `missing_video_ids` achieved from **missing.txt** file.
# - If video is available, the start frame, end frame, category (test, train or split), corresponding label and video name is stored.
# - These lists are stored for further data processing later on.
# - The progress and data count is checked at the end to ensure all data samples were included - a total of 21083 samples with 2000 labels.

# %%
gloss_list = []
video_name_list = []
start_frame = []
end_frame = []
category_list = []
vid_dir = main_path + '/videos'
progress = 0
data_count = 0

# looping through each word / gesture
for word in data:
    # getting the all instances of each word for easy testing of code
    for i in range(len(word['instances'])):

        # if video is missing, skip it
        if any(word["instances"][i]["video_id"] in line for line in missing_video_ids):
            continue

        # get the video path
        vid_name = os.path.join(
            vid_dir, f'{word["instances"][i]["video_id"]}.mp4')

        # get the start, end frame and the label
        start = word['instances'][i]['frame_start']
        end = word['instances'][i]['frame_end']
        label = word['gloss']
        category = word['instances'][i]['split']

        # adding to the list
        video_name_list.append(vid_name)
        gloss_list.append(label)
        start_frame.append(start)
        end_frame.append(end)
        category_list.append(category)

        # updating progress after each loop
        progress += 1
        data_count += 1

print(data_count)
# Out:
# 21083

# %%
unique_words_count = len(set(gloss_list))
print(
    f'number of unique words = {unique_words_count}\nnumber of videos = {len(video_name_list)}')
print(video_name_list)
# Out:
# number of unique words = 2000
# number of videos = 21083
# ['./dataset//videos\\69241.mp4', './dataset//videos\\65225.mp4', './dataset//videos\\68011.mp4', './dataset//videos\\68208.mp4', './dataset//videos\\68012.mp4', './dataset//videos\\70212.mp4', './dataset//videos\\70266.mp4', './dataset//videos\\07085.mp4', './dataset//videos\\07086.mp4', './dataset//videos\\07087.mp4', './dataset//videos\\07069.mp4', './dataset//videos\\07088.mp4', './dataset//videos\\07089.mp4', './dataset//videos\\07090.mp4', './dataset//videos\\07091.mp4', './dataset//videos\\07092.mp4', './dataset//videos\\07093.mp4', './dataset//videos\\07068.mp4', './dataset//videos\\07094.mp4', './dataset//videos\\07095.mp4', './dataset//videos\\07096.mp4', './dataset//videos\\07097.mp4', './dataset//videos\\07070.mp4', './dataset//videos\\07098.mp4', './dataset//videos\\07099.mp4', './dataset//videos\\07071.mp4', './dataset//videos\\07072.mp4', './dataset//videos\\07073.mp4', './dataset//videos\\67424.mp4', './dataset//videos\\07074.mp4', './dataset//videos\\07075.mp4', './dataset//videos\\07076.mp4', './dataset//videos\\07077.mp4', './dataset//videos\\07078.mp4', './dataset//videos\\07079.mp4', './dataset//videos\\07080.mp4', './dataset//videos\\07081.mp4', './dataset//videos\\07082.mp4', './dataset//videos\\07083.mp4', './dataset//videos\\07084.mp4', './dataset//videos\\69302.mp4', './dataset//videos\\65539.mp4', './dataset//videos\\70173.mp4', './dataset//videos\\68538.mp4', './dataset//videos\\68042.mp4', './dataset//videos\\68660.mp4', './dataset//videos\\68041.mp4', './dataset//videos\\17725.mp4', './dataset//videos\\17726.mp4', './dataset//videos\\17727.mp4', './dataset//videos\\17728.mp4', './dataset//videos\\17710.mp4', './dataset//videos\\17729.mp4', './dataset//videos\\17730.mp4', './dataset//videos\\17731.mp4', './dataset//videos\\17732.mp4', './dataset//videos\\17733.mp4', './dataset//videos\\65540.mp4', './dataset//videos\\17734.mp4', './dataset//videos\\17711.mp4', './dataset//videos\\17712.mp4', './dataset//videos\\17713.mp4', './dataset//videos\\17714.mp4', './dataset//videos\\17715.mp4', './dataset//videos\\17716.mp4', './dataset//videos\\17717.mp4', './dataset//videos\\17718.mp4', './dataset//videos\\17709.mp4', './dataset//videos\\67594.mp4', './dataset//videos\\17719.mp4', './dataset//videos\\17720.mp4', './dataset//videos\\17721.mp4', './dataset//videos\\17722.mp4', './dataset//videos\\17723.mp4', './dataset//videos\\17724.mp4', './dataset//videos\\12306.mp4', './dataset//videos\\68028.mp4', './dataset//videos\\69054.mp4', './dataset//videos\\12328.mp4', './dataset//videos\\12329.mp4', './dataset//videos\\12330.mp4', './dataset//videos\\12312.mp4', './dataset//videos\\12331.mp4', './dataset//videos\\12332.mp4', './dataset//videos\\12333.mp4', './dataset//videos\\12335.mp4', './dataset//videos\\12336.mp4', './dataset//videos\\12311.mp4', './dataset//videos\\12337.mp4', './dataset//videos\\12338.mp4', './dataset//videos\\12313.mp4', './dataset//videos\\12314.mp4', './dataset//videos\\12315.mp4', './dataset//videos\\12316.mp4', './dataset//videos\\12317.mp4', './dataset//videos\\12318.mp4', './dataset//videos\\12319.mp4', './dataset//videos\\12320.mp4', './dataset//videos\\67519.mp4', './dataset//videos\\12321.mp4', './dataset//videos\\12322.mp4', './dataset//videos\\12323.mp4', './dataset//videos\\12324.mp4', './dataset//videos\\12326.mp4', './dataset//videos\\12327.mp4', './dataset//videos\\05724.mp4', './dataset//videos\\70348.mp4', './dataset//videos\\68007.mp4', './dataset//videos\\05744.mp4', './dataset//videos\\05746.mp4', './dataset//videos\\05728.mp4', './dataset//videos\\05747.mp4', './dataset//videos\\05748.mp4', './dataset//videos\\05749.mp4', './dataset//videos\\05750.mp4', './dataset//videos\\05729.mp4', './dataset//videos\\05730.mp4', './dataset//videos\\65167.mp4', './dataset//videos\\05731.mp4', './dataset//videos\\05732.mp4', './dataset//videos\\05733.mp4', './dataset//videos\\05734.mp4', './dataset//videos\\05735.mp4', './dataset//videos\\05736.mp4', './dataset//videos\\05727.mp4', ...

# %%
del data, unique_words_count, word, progress
gc.collect()
# Out:
# 0

# %% [markdown]
# # Collect Keypoint Values From Videos

# %% [markdown]
# ### Extracting Keypoints From A Frame

# %% [markdown]
# **Landmarks**
#
# - **Hands:** 42 (21 on each hand)
# - **Pose:** 6 landmarks for the upper body excluding the face
# - **Face:** 132 out of the 478 landmarks, focusing on the lips, eyes, eyebrows, and the outline of the face
# - **Total number of landmarks:** 180, each with coordinates (x, y, z)

# %%
filtered_face = [0, 4, 7, 8, 10, 13, 14, 17, 21, 33, 37, 39, 40, 46, 52, 53, 54, 55, 58,
                 61, 63, 65, 66, 67, 70, 78, 80, 81, 82, 84, 87, 88, 91, 93, 95, 103, 105,
                 107, 109, 127, 132, 133, 136, 144, 145, 146, 148, 149, 150, 152, 153, 154,
                 155, 157, 158, 159, 160, 161, 162, 163, 172, 173, 176, 178, 181, 185, 191,
                 234, 246, 249, 251, 263, 267, 269, 270, 276, 282, 283, 284, 285, 288, 291,
                 293, 295, 296, 297, 300, 308, 310, 311, 312, 314, 317, 318, 321, 323, 324,
                 332, 334, 336, 338, 356, 361, 362, 365, 373, 374, 375, 377, 378, 379, 380,
                 381, 382, 384, 385, 386, 387, 388, 389, 390, 397, 398, 400, 402, 405, 409,
                 415, 454, 466, 468, 473]

filtered_pose = [11, 12, 13, 14, 15, 16]

FACE_NUM = len(filtered_face)
POSE_NUM = len(filtered_pose)
HAND_NUM = 21  # per hand

# %% [markdown]
# #### Centering The Landmarks

# %% [markdown]
# `adjust_3d_landmarks` takes a set of coordinates and centers them by subtracting each 3D coordinates from the specified center. The array containing the set of coordinates is reshaped first to perform the centering on the whole array.

# %%
def adjust_3d_landmarks(arr, center):
    # the array reshaped to have shape (n*m, 3)
    arr_reshaped = arr.reshape(-1, 3)

    # the center array repeated to have shape (n*m, 3)
    center_repeated = np.tile(center, (len(arr_reshaped), 1))

    # the center array subtracted from the arr array
    arr_adjusted = arr_reshaped - center_repeated

    # arr_adjusted reshaped back to shape (n, m, 3)
    arr_adjusted = arr_adjusted.reshape(arr.shape)

    return arr_adjusted

# %% [markdown]
# #### Mediapipe Implementation

# %% [markdown]
# The function takes in a frame and extracts landmarks from it using MediaPipe's landmark extraction models for tracking hands, pose and face.
#
# - First, instances of the MediaPipe models are created
# - `get_frame_landmarks` function takes in a video frame as a parameter and extract landmarks for hands, pose and hands using additional functions.
# - `get_hands`, `get_pose` and `get_face` processes the frame using the instances of MediaPipe models created earlier.
# - The obtained landmarks are filtered to include the landmarks that were chosen to be included.
# - `adjust_3d_landmarks` is called at the end of each of these three functions to center the landmarks.
# - The functions store the adjusted landmarks in their respective indices in an array `all_landmarks`
# - Threading is used here to perform these extraction concurrently for efficiency.
# - At the end of landmark extraction when threads have finished executing, `all_landmarks` are returned in a single array by the function.

# %%
# instances created for hand, pose and face tracking
hands = mp.solutions.hands.Hands()

pose = mp.solutions.pose.Pose()

face_mesh = mp.solutions.face_mesh.FaceMesh(refine_landmarks=True)



def get_frame_landmarks(frame):
    # 3d array to store landmark for each frame
    all_landmarks = np.zeros((HAND_NUM * 2 + POSE_NUM + FACE_NUM, 3))

    def get_hands(frame):
        results_hands = hands.process(frame)
        if results_hands.multi_hand_landmarks:
            # print("HAND:")
            # print(results_hands.multi_hand_landmarks)
            # iterate over each set of hand landmarks

            for i, hand_landmarks in enumerate(results_hands.multi_hand_landmarks):
                # left hand = 0, right hand = 1
                # left hand

                if results_hands.multi_handedness[i].classification[0].index == 0:
                    hands_landmarks = np.array([(lm.x, lm.y, lm.z) for lm in hand_landmarks.landmark])
                    hands_center = hands_landmarks[0, :3]

                    hands_adjusted = adjust_3d_landmarks(hands_landmarks, hands_center)
                    all_landmarks[:HAND_NUM, :] = hands_adjusted

                else:  # right hand

                    hands_landmarks = np.array([(lm.x, lm.y, lm.z) for lm in hand_landmarks.landmark])
                    hands_center = hands_landmarks[0, :3]

                    hands_adjusted = adjust_3d_landmarks(hands_landmarks, hands_center)
                    all_landmarks[HAND_NUM:HAND_NUM * 2, :] = hands_adjusted

            # print("HAND:")
            # print(hands_adjusted)


    def get_pose(frame):
        results_pose = pose.process(frame)

        if results_pose.pose_landmarks:
            # print("POSE: ")
            # print(results_pose.pose_landmarks)
            poses_landmarks = np.array([(lm.x, lm.y, lm.z) for lm in results_pose.pose_landmarks.landmark])[filtered_pose]
            pose_center = poses_landmarks[0, :3]

            pose_adjusted = adjust_3d_landmarks(poses_landmarks, pose_center)
            all_landmarks[HAND_NUM * 2:HAND_NUM * 2 + POSE_NUM, :] = pose_adjusted

    def get_face(frame):
        results_face = face_mesh.process(frame)
        if results_face.multi_face_landmarks:
            # print("FACE: ")
            # print(results_face.multi_face_landmarks)

            face = np.array([(lm.x, lm.y, lm.z) for lm in results_face.multi_face_landmarks[0].landmark])[filtered_face]
            face_center = face[0, :3]

            face_adjusted = adjust_3d_landmarks(face, face_center)
            all_landmarks[HAND_NUM * 2 + POSE_NUM:, :] = face_adjusted


    # threading for concurrent operation on all 3 landmark locations for each frame
    threads = []
    threads.append(threading.Thread(target=get_hands, args=(frame,)))
    threads.append(threading.Thread(target=get_pose, args=(frame,)))
    threads.append(threading.Thread(target=get_face, args=(frame,)))

    for thread in threads:
        thread.start()

    for thread in threads:
        thread.join()

    return all_landmarks

# %% [markdown]
# ### Extracting Keypoints From A Video

# %% [markdown]
# `get_video_landmarks` processes a video frame by frame to obtain all landmarks for one single video.
#
# - The function takes a video path, its start and end frame as parameters and opens the specificied video file using OpenCV.
# - If the `start_frame` or `end_frame` is out of bounds, it is adjusted accordingly. The `start_frame` is set to 1 and `end_frame` is set to the frame count of the video obtained by OpenCV.
# - An array `all_frame_landmarks` is initialized which will be used to store all the landmarks for a video.
# - Using OpenCV, the video frames are iterated.
# - The color format is converted from BGR to RGB as MediaPipe works with RGB images.
# - The frame is then passed as parameter to the previously defined `get_frame_landmarks` function to obtain landmarks for that frame.
# - Obtained landmarks are stored in the `all_frame_landmarks` array and the video capture object is released so resources are freed up.
# - The models are reset for the processing of next video processing.
# - The landmarks are then returned by function.

# %%
def get_video_landmarks(video_path, start_frame=1, end_frame=-1):
    cap = cv2.VideoCapture(video_path)

    # check if start frame less than 1
    if start_frame <= 1:
        start_frame = 1
    # if the start frame exceeds the maximum number of frames
    elif start_frame > int(cap.get(cv2.CAP_PROP_FRAME_COUNT)):
        start_frame = 1
        end_frame = int(cap.get(cv2.CAP_PROP_FRAME_COUNT)) # set to maximum

    # if the final frame was not given (-1)
    if end_frame < 0:
        # end frame = max frame
        end_frame = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

    num_landmarks = HAND_NUM * 2 + POSE_NUM + FACE_NUM
    all_frame_landmarks = np.zeros((end_frame - start_frame + 1, num_landmarks, 3))
    frame_index = 1

    while cap.isOpened() and frame_index <= end_frame:
        # ret returns value which indicates if frame was properly read or not
        ret, frame = cap.read()
        if not ret: 
            break
        # frames before start frame are skipped
        if frame_index >= start_frame:
            frame.flags.writeable = False
            frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            frame_landmarks = get_frame_landmarks(frame)
            all_frame_landmarks[frame_index - start_frame] = frame_landmarks

        frame_index += 1

    # the video capture object is released
    cap.release()
    
    # the state of the hands, pose, and face_mesh models is reset
    hands.reset()
    pose.reset()
    face_mesh.reset()
    return all_frame_landmarks

# %% [markdown]
# # Collecting And Saving Keypoints

# %% [markdown]
# ### Encoding And Saving Data

# %% [markdown]
# Landmarks obtained are set up to be stored in numpy format in specific directories depending on their categorization (train, validation or test split).
#
# The functions defined previously are called to obtain the landmarks and store them in respective directories as numpy arrays in **.npy** format.
# - Each data sample is iterated and a `npy_path` is set based on its split category.
# - Before extracting landmarks, it is checked if the npy file already exists. if it does, then it skips that data sample.
# - The video path, start frame and end frame is collected from the lists created at the beginning of the project and are passed as parameters to the function `get_video_landmarks` to get the 3D landmarks for the specified video.
# - The landmarks is stored as a numpy file at the path specified by `npy_path`
# - A message is printed to indicate that the numpy was saved successfully.

# %%
# storing the keypoints in a folder
numpy_dir = main_path + 'new_preprocessed-data'
if not os.path.exists(numpy_dir):
    os.mkdir(numpy_dir)

numpy_dir_1 = numpy_dir + '/train'
numpy_dir_2 = numpy_dir + '/val'
numpy_dir_3 = numpy_dir + '/test'

if not os.path.exists(numpy_dir_1):
    os.mkdir(numpy_dir_1)
if not os.path.exists(numpy_dir_2):
    os.mkdir(numpy_dir_2)
if not os.path.exists(numpy_dir_3):
    os.mkdir(numpy_dir_3)

# %%
# data_count is the number of dataset

for i in tqdm(range(data_count), ncols=100):
    # specify the path for the test npy to be saved
    npy_path = f'{main_path}new_preprocessed-data/{category_list[i]}/{i}.npy'

    # Check if the file already exists
    if os.path.exists(npy_path):
        print(f"File {npy_path} already exists..")
        continue

    # getting the video information
    input_path = video_name_list[i]
    start = start_frame[i]
    end = end_frame[i]

    # getting the landmarks for the specified frame range
    npyArray = get_video_landmarks(input_path, start, end)
    # print(npyArray)

    # saving the file
    np.save(npy_path, npyArray)
    print(f"{category_list[i]}/{i}.npy has been saved")
# Out:
#   1%|▍                                                        | 144/21083 [00:00<00:14, 1416.51it/s]
# File ./dataset/new_preprocessed-data/train/0.npy already exists..
# File ./dataset/new_preprocessed-data/train/1.npy already exists..
# File ./dataset/new_preprocessed-data/train/2.npy already exists..
# File ./dataset/new_preprocessed-data/train/3.npy already exists..
# File ./dataset/new_preprocessed-data/train/4.npy already exists..
# File ./dataset/new_preprocessed-data/val/5.npy already exists..
# File ./dataset/new_preprocessed-data/train/6.npy already exists..
# File ./dataset/new_preprocessed-data/train/7.npy already exists..
# File ./dataset/new_preprocessed-data/train/8.npy already exists..
# File ./dataset/new_preprocessed-data/train/9.npy already exists..
# File ./dataset/new_preprocessed-data/train/10.npy already exists..
# File ./dataset/new_preprocessed-data/train/11.npy already exists..
# File ./dataset/new_preprocessed-data/train/12.npy already exists..
# File ./dataset/new_preprocessed-data/train/13.npy already exists..
# File ./dataset/new_preprocessed-data/train/14.npy already exists..
# File ./dataset/new_preprocessed-data/test/15.npy already exists..
# File ./dataset/new_preprocessed-data/test/16.npy already exists..
# File ./dataset/new_preprocessed-data/train/17.npy already exists..
# File ./dataset/new_preprocessed-data/val/18.npy already exists..
# File ./dataset/new_preprocessed-data/test/19.npy already exists..
# File ./dataset/new_preprocessed-data/val/20.npy already exists..
# File ./dataset/new_preprocessed-data/train/21.npy already exists..
# File ./dataset/new_preprocessed-data/train/22.npy already exists..
# File ./dataset/new_preprocessed-data/val/23.npy already exists..
# File ./dataset/new_preprocessed-data/val/24.npy already exists..
# File ./dataset/new_preprocessed-data/train/25.npy already exists..
# File ./dataset/new_preprocessed-data/test/26.npy already exists..
# File ./dataset/new_preprocessed-data/train/27.npy already exists..
# File ./dataset/new_preprocessed-data/train/28.npy already exists..
# File ./dataset/new_preprocessed-data/train/29.npy already exists..
# File ./dataset/new_preprocessed-data/train/30.npy already exists..
# File ./dataset/new_preprocessed-data/train/31.npy already exists..
# File ./dataset/new_preprocessed-data/train/32.npy already exists..
# File ./dataset/new_preprocessed-data/train/33.npy already exists..
# File ./dataset/new_preprocessed-data/train/34.npy already exists..
# File ./dataset/new_preprocessed-data/train/35.npy already exists..
# File ./dataset/new_preprocessed-data/train/36.npy already exists..
# File ./dataset/new_preprocessed-data/train/37.npy already exists..
# File ./dataset/new_preprocessed-data/val/38.npy already exists..
# File ./dataset/new_preprocessed-data/train/39.npy already exists..
# File ./dataset/new_preprocessed-data/val/40.npy already exists..
# File ./dataset/new_preprocessed-data/train/41.npy already exists..
# File ./dataset/new_preprocessed-data/val/42.npy already exists..
# File ./dataset/new_preprocessed-data/val/43.npy already exists..
# File ./dataset/new_preprocessed-data/val/44.npy already exists..
# File ./dataset/new_preprocessed-data/train/45.npy already exists..
# File ./dataset/new_preprocessed-data/train/46.npy already exists..
# File ./dataset/new_preprocessed-data/train/47.npy already exists..
# File ./dataset/new_preprocessed-data/train/48.npy already exists..
# File ./dataset/new_preprocessed-data/train/49.npy already exists..
# File ./dataset/new_preprocessed-data/train/50.npy already exists..
# File ./dataset/new_preprocessed-data/train/51.npy already exists..
# File ./dataset/new_preprocessed-data/train/52.npy already exists..
# File ./dataset/new_preprocessed-data/test/53.npy already exists..
# File ./dataset/new_preprocessed-data/train/54.npy already exists..
# File ./dataset/new_preprocessed-data/train/55.npy already exists..
# File ./dataset/new_preprocessed-data/train/56.npy already exists..
# File ./dataset/new_preprocessed-data/train/57.npy already exists..
# File ./dataset/new_preprocessed-data/val/58.npy already exists..
# File ./dataset/new_preprocessed-data/train/59.npy already exists..
# File ./dataset/new_preprocessed-data/train/60.npy already exists..
# File ./dataset/new_preprocessed-data/test/61.npy already exists..
# File ./dataset/new_preprocessed-data/train/62.npy already exists..
# File ./dataset/new_preprocessed-data/train/63.npy already exists..
# File ./dataset/new_preprocessed-data/test/64.npy already exists..
# File ./dataset/new_preprocessed-data/train/65.npy already exists..
# File ./dataset/new_preprocessed-data/test/66.npy already exists..
# File ./dataset/new_preprocessed-data/train/67.npy already exists..
# File ./dataset/new_preprocessed-data/train/68.npy already exists..
# File ./dataset/new_preprocessed-data/train/69.npy already exists..
# File ./dataset/new_preprocessed-data/train/70.npy already exists..
# File ./dataset/new_preprocessed-data/train/71.npy already exists..
# File ./dataset/new_preprocessed-data/train/72.npy already exists..
# File ./dataset/new_preprocessed-data/train/73.npy already exists..
# File ./dataset/new_preprocessed-data/val/74.npy already exists..
# File ./dataset/new_preprocessed-data/test/75.npy already exists..
# File ./dataset/new_preprocessed-data/train/76.npy already exists..
# File ./dataset/new_preprocessed-data/train/77.npy already exists..
# File ./dataset/new_preprocessed-data/train/78.npy already exists..
# File ./dataset/new_preprocessed-data/train/79.npy already exists..
# File ./dataset/new_preprocessed-data/train/80.npy already exists..
# File ./dataset/new_preprocessed-data/val/81.npy already exists..
# File ./dataset/new_preprocessed-data/train/82.npy already exists..
# File ./dataset/new_preprocessed-data/test/83.npy already exists..
# File ./dataset/new_preprocessed-data/val/84.npy already exists..
# File ./dataset/new_preprocessed-data/val/85.npy already exists..
# File ./dataset/new_preprocessed-data/test/86.npy already exists..
# File ./dataset/new_preprocessed-data/train/87.npy already exists..
# File ./dataset/new_preprocessed-data/train/88.npy already exists..
# File ./dataset/new_preprocessed-data/train/89.npy already exists..
# File ./dataset/new_preprocessed-data/train/90.npy already exists..
# File ./dataset/new_preprocessed-data/train/91.npy already exists..
# File ./dataset/new_preprocessed-data/val/92.npy already exists..
# File ./dataset/new_preprocessed-data/train/93.npy already exists..
# File ./dataset/new_preprocessed-data/train/94.npy already exists..
# File ./dataset/new_preprocessed-data/train/95.npy already exists..
# File ./dataset/new_preprocessed-data/train/96.npy already exists..
# File ./dataset/new_preprocessed-data/test/97.npy already exists..
# File ./dataset/new_preprocessed-data/test/98.npy already exists..
# File ./dataset/new_preprocessed-data/train/99.npy already exists..
# File ./dataset/new_preprocessed-data/train/100.npy already exists..
# File ./dataset/new_preprocessed-data/train/101.npy already exists..
# File ./dataset/new_preprocessed-data/train/102.npy already exists..
# File ./dataset/new_preprocessed-data/val/103.npy already exists..
# File ./dataset/new_preprocessed-data/train/104.npy already exists..
# File ./dataset/new_preprocessed-data/train/105.npy already exists..
# File ./dataset/new_preprocessed-data/train/106.npy already exists..
# File ./dataset/new_preprocessed-data/train/107.npy already exists..
# File ./dataset/new_preprocessed-data/train/108.npy already exists..
# File ./dataset/new_preprocessed-data/val/109.npy already exists..
# File ./dataset/new_preprocessed-data/train/110.npy already exists..
# File ./dataset/new_preprocessed-data/train/111.npy already exists..
# File ./dataset/new_preprocessed-data/train/112.npy already exists..
# File ./dataset/new_preprocessed-data/train/113.npy already exists..
# File ./dataset/new_preprocessed-data/val/114.npy already exists..
# File ./dataset/new_preprocessed-data/train/115.npy already exists..
# File ./dataset/new_preprocessed-data/train/116.npy already exists..
# File ./dataset/new_preprocessed-data/train/117.npy already exists..
# File ./dataset/new_preprocessed-data/train/118.npy already exists..
# File ./dataset/new_preprocessed-data/train/119.npy already exists..
# File ./dataset/new_preprocessed-data/train/120.npy already exists..
# File ./dataset/new_preprocessed-data/train/121.npy already exists..
# File ./dataset/new_preprocessed-data/test/122.npy already exists..
# File ./dataset/new_preprocessed-data/val/123.npy already exists..
# File ./dataset/new_preprocessed-data/test/124.npy already exists..
# File ./dataset/new_preprocessed-data/val/125.npy already exists..
# File ./dataset/new_preprocessed-data/test/126.npy already exists..
# File ./dataset/new_preprocessed-data/train/127.npy already exists..
# File ./dataset/new_preprocessed-data/test/128.npy already exists..
# File ./dataset/new_preprocessed-data/train/129.npy already exists..
# File ./dataset/new_preprocessed-data/train/130.npy already exists..
# File ./dataset/new_preprocessed-data/test/131.npy already exists..
# File ./dataset/new_preprocessed-data/train/132.npy already exists..
# File ./dataset/new_preprocessed-data/train/133.npy already exists..
# File ./dataset/new_preprocessed-data/train/134.npy already exists..
# File ./dataset/new_preprocessed-data/train/135.npy already exists..
# File ./dataset/new_preprocessed-data/train/136.npy already exists..
# File ./dataset/new_preprocessed-data/train/137.npy already exists..
# File ./dataset/new_preprocessed-data/train/138.npy already exists..
# File ./dataset/new_preprocessed-data/test/139.npy already exists..
# File ./dataset/new_preprocessed-data/train/140.npy already exists..
# File ./dataset/new_preprocessed-data/train/141.npy already exists..
# File ./dataset/new_preprocessed-data/train/142.npy already exists..
# File ./dataset/new_preprocessed-data/val/143.npy already exists..
# File ./dataset/new_preprocessed-data/train/144.npy already exists..
# File ./dataset/new_preprocessed-data/train/145.npy already exists..
# File ./dataset/new_preprocessed-data/val/146.npy already exists..
# File ./dataset/new_preprocessed-data/test/147.npy already exists..
# File ./dataset/new_preprocessed-data/train/148.npy already exists..
# File ./dataset/new_preprocessed-data/val/149.npy already exists..
# File ./dataset/new_preprocessed-data/train/150.npy already exists..
# File ./dataset/new_preprocessed-data/train/151.npy already exists..
# File ./dataset/new_preprocessed-data/train/152.npy already exists..
# File ./dataset/new_preprocessed-data/train/153.npy already exists..
# File ./dataset/new_preprocessed-data/train/154.npy already exists..
# File ./dataset/new_preprocessed-data/val/155.npy already exists..
# File ./dataset/new_preprocessed-data/train/156.npy already exists..
# File ./dataset/new_preprocessed-data/test/157.npy already exists..
# File ./dataset/new_preprocessed-data/val/158.npy already exists..
# File ./dataset/new_preprocessed-data/train/159.npy already exists..
# File ./dataset/new_preprocessed-data/train/160.npy already exists..
# File ./dataset/new_preprocessed-data/train/161.npy already exists..
# File ./dataset/new_preprocessed-data/train/162.npy already exists..
# File ./dataset/new_preprocessed-data/test/163.npy already exists..
# File ./dataset/new_preprocessed-data/train/164.npy already exists..
# File ./dataset/new_preprocessed-data/train/165.npy already exists..
# File ./dataset/new_preprocessed-data/train/166.npy already exists..
# File ./dataset/new_preprocessed-data/train/167.npy already exists..
# File ./dataset/new_preprocessed-data/train/168.npy already exists..
# File ./dataset/new_preprocessed-data/train/169.npy already exists..
# File ./dataset/new_preprocessed-data/train/170.npy already exists..
# File ./dataset/new_preprocessed-data/train/171.npy already exists..
# File ./dataset/new_preprocessed-data/train/172.npy already exists..
# File ./dataset/new_preprocessed-data/train/173.npy already exists..
# File ./dataset/new_preprocessed-data/val/174.npy already exists..
# File ./dataset/new_preprocessed-data/train/175.npy already exists..
# File ./dataset/new_preprocessed-data/val/176.npy already exists..
# File ./dataset/new_preprocessed-data/train/177.npy already exists..
# File ./dataset/new_preprocessed-data/test/178.npy already exists..
# File ./dataset/new_preprocessed-data/train/179.npy already exists..
# File ./dataset/new_preprocessed-data/train/180.npy already exists..
# File ./dataset/new_preprocessed-data/val/181.npy already exists..
# File ./dataset/new_preprocessed-data/train/182.npy already exists..
# File ./dataset/new_preprocessed-data/test/183.npy already exists..
# File ./dataset/new_preprocessed-data/train/184.npy already exists..
# File ./dataset/new_preprocessed-data/train/185.npy already exists..
# File ./dataset/new_preprocessed-data/train/186.npy already exists..
# File ./dataset/new_preprocessed-data/train/187.npy already exists..
# File ./dataset/new_preprocessed-data/train/188.npy already exists..
# File ./dataset/new_preprocessed-data/train/189.npy already exists..
# File ./dataset/new_preprocessed-data/train/190.npy already exists..
# File ./dataset/new_preprocessed-data/test/191.npy already exists..
# File ./dataset/new_preprocessed-data/train/192.npy already exists..
# File ./dataset/new_preprocessed-data/train/193.npy already exists..
# File ./dataset/new_preprocessed-data/val/194.npy already exists..
# File ./dataset/new_preprocessed-data/val/195.npy already exists..
# File ./dataset/new_preprocessed-data/train/196.npy already exists..
# File ./dataset/new_preprocessed-data/train/197.npy already exists..
# File ./dataset/new_preprocessed-data/train/198.npy already exists..
# File ./dataset/new_preprocessed-data/test/199.npy already exists..
# File ./dataset/new_preprocessed-data/val/200.npy already exists..
# File ./dataset/new_preprocessed-data/train/201.npy already exists..
# File ./dataset/new_preprocessed-data/train/202.npy already exists..
# File ./dataset/new_preprocessed-data/train/203.npy already exists..
# File ./dataset/new_preprocessed-data/train/204.npy already exists..
# File ./dataset/new_preprocessed-data/train/205.npy already exists..
# File ./dataset/new_preprocessed-data/val/206.npy already exists..
# File ./dataset/new_preprocessed-data/train/207.npy already exists..
# File ./dataset/new_preprocessed-data/test/208.npy already exists..
# File ./dataset/new_preprocessed-data/train/209.npy already exists..
# File ./dataset/new_preprocessed-data/train/210.npy already exists..
# File ./dataset/new_preprocessed-data/train/211.npy already exists..
# File ./dataset/new_preprocessed-data/train/212.npy already exists..
# File ./dataset/new_preprocessed-data/train/213.npy already exists..
# File ./dataset/new_preprocessed-data/train/214.npy already exists..
# File ./dataset/new_preprocessed-data/train/215.npy already exists..
# File ./dataset/new_preprocessed-data/test/216.npy already exists..
# File ./dataset/new_preprocessed-data/train/217.npy already exists..
# File ./dataset/new_preprocessed-data/train/218.npy already exists..
# File ./dataset/new_preprocessed-data/val/219.npy already exists..
# File ./dataset/new_preprocessed-data/val/220.npy already exists..
# File ./dataset/new_preprocessed-data/train/221.npy already exists..
# File ./dataset/new_preprocessed-data/train/222.npy already exists..
# File ./dataset/new_preprocessed-data/train/223.npy already exists..
# File ./dataset/new_preprocessed-data/test/224.npy already exists..
# File ./dataset/new_preprocessed-data/val/225.npy already exists..
# File ./dataset/new_preprocessed-data/train/226.npy already exists..
# File ./dataset/new_preprocessed-data/train/227.npy already exists..
# File ./dataset/new_preprocessed-data/train/228.npy already exists..
# File ./dataset/new_preprocessed-data/train/229.npy already exists..
# File ./dataset/new_preprocessed-data/train/230.npy already exists..
# File ./dataset/new_preprocessed-data/val/231.npy already exists..
# File ./dataset/new_preprocessed-data/train/232.npy already exists..
# File ./dataset/new_preprocessed-data/train/233.npy already exists..
# File ./dataset/new_preprocessed-data/train/234.npy already exists..
# File ./dataset/new_preprocessed-data/train/235.npy already exists..
# File ./dataset/new_preprocessed-data/train/236.npy already exists..
# File ./dataset/new_preprocessed-data/train/237.npy already exists..
# File ./dataset/new_preprocessed-data/val/238.npy already exists..
# File ./dataset/new_preprocessed-data/train/239.npy already exists..
# File ./dataset/new_preprocessed-data/train/240.npy already exists..
# File ./dataset/new_preprocessed-data/val/241.npy already exists..
# File ./dataset/new_preprocessed-data/train/242.npy already exists..
# File ./dataset/new_preprocessed-data/train/243.npy already exists..
# File ./dataset/new_preprocessed-data/train/244.npy already exists..
# File ./dataset/new_preprocessed-data/val/245.npy already exists..
# File ./dataset/new_preprocessed-data/train/246.npy already exists..
# File ./dataset/new_preprocessed-data/train/247.npy already exists..
# File ./dataset/new_preprocessed-data/train/248.npy already exists..
# File ./dataset/new_preprocessed-data/train/249.npy already exists..
# File ./dataset/new_preprocessed-data/test/250.npy already exists..
# File ./dataset/new_preprocessed-data/test/251.npy already exists..
# File ./dataset/new_preprocessed-data/val/252.npy already exists..
# File ./dataset/new_preprocessed-data/train/253.npy already exists..
# File ./dataset/new_preprocessed-data/test/254.npy already exists..
# File ./dataset/new_preprocessed-data/train/255.npy already exists..
# File ./dataset/new_preprocessed-data/train/256.npy already exists..
# File ./dataset/new_preprocessed-data/test/257.npy already exists..
# File ./dataset/new_preprocessed-data/train/258.npy already exists..
# File ./dataset/new_preprocessed-data/train/259.npy already exists..
# File ./dataset/new_preprocessed-data/train/260.npy already exists..
# File ./dataset/new_preprocessed-data/train/261.npy already exists..
# File ./dataset/new_preprocessed-data/train/262.npy already exists..
# File ./dataset/new_preprocessed-data/train/263.npy already exists..
# File ./dataset/new_preprocessed-data/val/264.npy already exists..
# File ./dataset/new_preprocessed-data/val/265.npy already exists..
# File ./dataset/new_preprocessed-data/test/266.npy already exists..
# File ./dataset/new_preprocessed-data/train/267.npy already exists..
# File ./dataset/new_preprocessed-data/train/268.npy already exists..
# File ./dataset/new_preprocessed-data/train/269.npy already exists..
# File ./dataset/new_preprocessed-data/train/270.npy already exists..
# File ./dataset/new_preprocessed-data/val/271.npy already exists..
# File ./dataset/new_preprocessed-data/test/272.npy already exists..
# File ./dataset/new_preprocessed-data/train/273.npy already exists..
# File ./dataset/new_preprocessed-data/val/274.npy already exists..
# File ./dataset/new_preprocessed-data/train/275.npy already exists..
# File ./dataset/new_preprocessed-data/train/276.npy already exists..
# File ./dataset/new_preprocessed-data/train/277.npy already exists..
# File ./dataset/new_preprocessed-data/train/278.npy already exists..
# File ./dataset/new_preprocessed-data/train/279.npy already exists..
# File ./dataset/new_preprocessed-data/test/280.npy already exists..
# File ./dataset/new_preprocessed-data/train/281.npy already exists..
# File ./dataset/new_preprocessed-data/train/282.npy already exists..
# File ./dataset/new_preprocessed-data/train/283.npy already exists..
#   3%|█▋                                                       | 628/21083 [00:00<00:12, 1598.43it/s]
# File ./dataset/new_preprocessed-data/train/284.npy already exists..
# File ./dataset/new_preprocessed-data/train/285.npy already exists..
# File ./dataset/new_preprocessed-data/train/286.npy already exists..
# File ./dataset/new_preprocessed-data/val/287.npy already exists..
# File ./dataset/new_preprocessed-data/val/288.npy already exists..
# File ./dataset/new_preprocessed-data/test/289.npy already exists..
# File ./dataset/new_preprocessed-data/train/290.npy already exists..
# File ./dataset/new_preprocessed-data/train/291.npy already exists..
# File ./dataset/new_preprocessed-data/train/292.npy already exists..
# File ./dataset/new_preprocessed-data/train/293.npy already exists..
# File ./dataset/new_preprocessed-data/val/294.npy already exists..
# File ./dataset/new_preprocessed-data/test/295.npy already exists..
# File ./dataset/new_preprocessed-data/train/296.npy already exists..
# File ./dataset/new_preprocessed-data/val/297.npy already exists..
# File ./dataset/new_preprocessed-data/train/298.npy already exists..
# File ./dataset/new_preprocessed-data/train/299.npy already exists..
# File ./dataset/new_preprocessed-data/train/300.npy already exists..
# File ./dataset/new_preprocessed-data/train/301.npy already exists..
# File ./dataset/new_preprocessed-data/train/302.npy already exists..
# File ./dataset/new_preprocessed-data/test/303.npy already exists..
# File ./dataset/new_preprocessed-data/test/304.npy already exists..
# File ./dataset/new_preprocessed-data/train/305.npy already exists..
# File ./dataset/new_preprocessed-data/train/306.npy already exists..
# File ./dataset/new_preprocessed-data/val/307.npy already exists..
# File ./dataset/new_preprocessed-data/val/308.npy already exists..
# File ./dataset/new_preprocessed-data/train/309.npy already exists..
# File ./dataset/new_preprocessed-data/train/310.npy already exists..
# File ./dataset/new_preprocessed-data/train/311.npy already exists..
# File ./dataset/new_preprocessed-data/test/312.npy already exists..
# File ./dataset/new_preprocessed-data/train/313.npy already exists..
# File ./dataset/new_preprocessed-data/train/314.npy already exists..
# File ./dataset/new_preprocessed-data/val/315.npy already exists..
# File ./dataset/new_preprocessed-data/train/316.npy already exists..
# File ./dataset/new_preprocessed-data/val/317.npy already exists..
# File ./dataset/new_preprocessed-data/train/318.npy already exists..
# File ./dataset/new_preprocessed-data/train/319.npy already exists..
# File ./dataset/new_preprocessed-data/train/320.npy already exists..
# File ./dataset/new_preprocessed-data/train/321.npy already exists..
# File ./dataset/new_preprocessed-data/train/322.npy already exists..
# File ./dataset/new_preprocessed-data/train/323.npy already exists..
# File ./dataset/new_preprocessed-data/train/324.npy already exists..
# File ./dataset/new_preprocessed-data/test/325.npy already exists..
# File ./dataset/new_preprocessed-data/val/326.npy already exists..
# File ./dataset/new_preprocessed-data/val/327.npy already exists..
# File ./dataset/new_preprocessed-data/val/328.npy already exists..
# File ./dataset/new_preprocessed-data/train/329.npy already exists..
# File ./dataset/new_preprocessed-data/train/330.npy already exists..
# File ./dataset/new_preprocessed-data/train/331.npy already exists..
# File ./dataset/new_preprocessed-data/train/332.npy already exists..
# File ./dataset/new_preprocessed-data/test/333.npy already exists..
# File ./dataset/new_preprocessed-data/train/334.npy already exists..
# File ./dataset/new_preprocessed-data/train/335.npy already exists..
# File ./dataset/new_preprocessed-data/train/336.npy already exists..
# File ./dataset/new_preprocessed-data/train/337.npy already exists..
# File ./dataset/new_preprocessed-data/test/338.npy already exists..
# File ./dataset/new_preprocessed-data/train/339.npy already exists..
# File ./dataset/new_preprocessed-data/val/340.npy already exists..
# File ./dataset/new_preprocessed-data/train/341.npy already exists..
# File ./dataset/new_preprocessed-data/train/342.npy already exists..
# File ./dataset/new_preprocessed-data/train/343.npy already exists..
# File ./dataset/new_preprocessed-data/train/344.npy already exists..
# File ./dataset/new_preprocessed-data/train/345.npy already exists..
# File ./dataset/new_preprocessed-data/train/346.npy already exists..
# File ./dataset/new_preprocessed-data/test/347.npy already exists..
# File ./dataset/new_preprocessed-data/val/348.npy already exists..
# File ./dataset/new_preprocessed-data/val/349.npy already exists..
# File ./dataset/new_preprocessed-data/val/350.npy already exists..
# File ./dataset/new_preprocessed-data/train/351.npy already exists..
# File ./dataset/new_preprocessed-data/train/352.npy already exists..
# File ./dataset/new_preprocessed-data/train/353.npy already exists..
# File ./dataset/new_preprocessed-data/train/354.npy already exists..
# File ./dataset/new_preprocessed-data/test/355.npy already exists..
# File ./dataset/new_preprocessed-data/train/356.npy already exists..
# File ./dataset/new_preprocessed-data/train/357.npy already exists..
# File ./dataset/new_preprocessed-data/train/358.npy already exists..
# File ./dataset/new_preprocessed-data/train/359.npy already exists..
# File ./dataset/new_preprocessed-data/test/360.npy already exists..
# File ./dataset/new_preprocessed-data/train/361.npy already exists..
# File ./dataset/new_preprocessed-data/val/362.npy already exists..
# File ./dataset/new_preprocessed-data/train/363.npy already exists..
# File ./dataset/new_preprocessed-data/train/364.npy already exists..
# File ./dataset/new_preprocessed-data/train/365.npy already exists..
# File ./dataset/new_preprocessed-data/train/366.npy already exists..
# File ./dataset/new_preprocessed-data/train/367.npy already exists..
# File ./dataset/new_preprocessed-data/train/368.npy already exists..
# File ./dataset/new_preprocessed-data/train/369.npy already exists..
# File ./dataset/new_preprocessed-data/val/370.npy already exists..
# File ./dataset/new_preprocessed-data/train/371.npy already exists..
# File ./dataset/new_preprocessed-data/train/372.npy already exists..
# File ./dataset/new_preprocessed-data/train/373.npy already exists..
# File ./dataset/new_preprocessed-data/train/374.npy already exists..
# File ./dataset/new_preprocessed-data/train/375.npy already exists..
# File ./dataset/new_preprocessed-data/train/376.npy already exists..
# File ./dataset/new_preprocessed-data/train/377.npy already exists..
# File ./dataset/new_preprocessed-data/train/378.npy already exists..
# File ./dataset/new_preprocessed-data/train/379.npy already exists..
# File ./dataset/new_preprocessed-data/train/380.npy already exists..
# File ./dataset/new_preprocessed-data/train/381.npy already exists..
# File ./dataset/new_preprocessed-data/test/382.npy already exists..
# File ./dataset/new_preprocessed-data/train/383.npy already exists..
# File ./dataset/new_preprocessed-data/val/384.npy already exists..
# File ./dataset/new_preprocessed-data/val/385.npy already exists..
# File ./dataset/new_preprocessed-data/train/386.npy already exists..
# File ./dataset/new_preprocessed-data/test/387.npy already exists..
# File ./dataset/new_preprocessed-data/test/388.npy already exists..
# File ./dataset/new_preprocessed-data/val/389.npy already exists..
# File ./dataset/new_preprocessed-data/train/390.npy already exists..
# File ./dataset/new_preprocessed-data/test/391.npy already exists..
# File ./dataset/new_preprocessed-data/val/392.npy already exists..
# File ./dataset/new_preprocessed-data/val/393.npy already exists..
# File ./dataset/new_preprocessed-data/val/394.npy already exists..
# File ./dataset/new_preprocessed-data/train/395.npy already exists..
# File ./dataset/new_preprocessed-data/train/396.npy already exists..
# File ./dataset/new_preprocessed-data/train/397.npy already exists..
# File ./dataset/new_preprocessed-data/train/398.npy already exists..
# File ./dataset/new_preprocessed-data/test/399.npy already exists..
# File ./dataset/new_preprocessed-data/train/400.npy already exists..
# File ./dataset/new_preprocessed-data/train/401.npy already exists..
# File ./dataset/new_preprocessed-data/train/402.npy already exists..
# File ./dataset/new_preprocessed-data/train/403.npy already exists..
# File ./dataset/new_preprocessed-data/test/404.npy already exists..
# File ./dataset/new_preprocessed-data/train/405.npy already exists..
# File ./dataset/new_preprocessed-data/val/406.npy already exists..
# File ./dataset/new_preprocessed-data/train/407.npy already exists..
# File ./dataset/new_preprocessed-data/train/408.npy already exists..
# File ./dataset/new_preprocessed-data/train/409.npy already exists..
# File ./dataset/new_preprocessed-data/train/410.npy already exists..
# File ./dataset/new_preprocessed-data/train/411.npy already exists..
# File ./dataset/new_preprocessed-data/train/412.npy already exists..
# File ./dataset/new_preprocessed-data/test/413.npy already exists..
# File ./dataset/new_preprocessed-data/val/414.npy already exists..
# File ./dataset/new_preprocessed-data/val/415.npy already exists..
# File ./dataset/new_preprocessed-data/val/416.npy already exists..
# File ./dataset/new_preprocessed-data/train/417.npy already exists..
# File ./dataset/new_preprocessed-data/train/418.npy already exists..
# File ./dataset/new_preprocessed-data/train/419.npy already exists..
# File ./dataset/new_preprocessed-data/train/420.npy already exists..
# File ./dataset/new_preprocessed-data/test/421.npy already exists..
# File ./dataset/new_preprocessed-data/train/422.npy already exists..
# File ./dataset/new_preprocessed-data/train/423.npy already exists..
# File ./dataset/new_preprocessed-data/train/424.npy already exists..
# File ./dataset/new_preprocessed-data/train/425.npy already exists..
# File ./dataset/new_preprocessed-data/test/426.npy already exists..
# File ./dataset/new_preprocessed-data/train/427.npy already exists..
# File ./dataset/new_preprocessed-data/val/428.npy already exists..
# File ./dataset/new_preprocessed-data/train/429.npy already exists..
# File ./dataset/new_preprocessed-data/train/430.npy already exists..
# File ./dataset/new_preprocessed-data/train/431.npy already exists..
# File ./dataset/new_preprocessed-data/train/432.npy already exists..
# File ./dataset/new_preprocessed-data/train/433.npy already exists..
# File ./dataset/new_preprocessed-data/train/434.npy already exists..
# File ./dataset/new_preprocessed-data/test/435.npy already exists..
# File ./dataset/new_preprocessed-data/val/436.npy already exists..
# File ./dataset/new_preprocessed-data/val/437.npy already exists..
# File ./dataset/new_preprocessed-data/val/438.npy already exists..
# File ./dataset/new_preprocessed-data/train/439.npy already exists..
# File ./dataset/new_preprocessed-data/train/440.npy already exists..
# File ./dataset/new_preprocessed-data/train/441.npy already exists..
# File ./dataset/new_preprocessed-data/train/442.npy already exists..
# File ./dataset/new_preprocessed-data/test/443.npy already exists..
# File ./dataset/new_preprocessed-data/train/444.npy already exists..
# File ./dataset/new_preprocessed-data/train/445.npy already exists..
# File ./dataset/new_preprocessed-data/train/446.npy already exists..
# File ./dataset/new_preprocessed-data/train/447.npy already exists..
# File ./dataset/new_preprocessed-data/test/448.npy already exists..
# File ./dataset/new_preprocessed-data/train/449.npy already exists..
# File ./dataset/new_preprocessed-data/val/450.npy already exists..
# File ./dataset/new_preprocessed-data/train/451.npy already exists..
# File ./dataset/new_preprocessed-data/train/452.npy already exists..
# File ./dataset/new_preprocessed-data/train/453.npy already exists..
# File ./dataset/new_preprocessed-data/train/454.npy already exists..
# File ./dataset/new_preprocessed-data/train/455.npy already exists..
# File ./dataset/new_preprocessed-data/train/456.npy already exists..
# File ./dataset/new_preprocessed-data/val/457.npy already exists..
# File ./dataset/new_preprocessed-data/train/458.npy already exists..
# File ./dataset/new_preprocessed-data/val/459.npy already exists..
# File ./dataset/new_preprocessed-data/test/460.npy already exists..
# File ./dataset/new_preprocessed-data/train/461.npy already exists..
# File ./dataset/new_preprocessed-data/train/462.npy already exists..
# File ./dataset/new_preprocessed-data/train/463.npy already exists..
# File ./dataset/new_preprocessed-data/train/464.npy already exists..
# File ./dataset/new_preprocessed-data/train/465.npy already exists..
# File ./dataset/new_preprocessed-data/train/466.npy already exists..
# File ./dataset/new_preprocessed-data/train/467.npy already exists..
# File ./dataset/new_preprocessed-data/train/468.npy already exists..
# File ./dataset/new_preprocessed-data/train/469.npy already exists..
# File ./dataset/new_preprocessed-data/train/470.npy already exists..
# File ./dataset/new_preprocessed-data/test/471.npy already exists..
# File ./dataset/new_preprocessed-data/train/472.npy already exists..
# File ./dataset/new_preprocessed-data/test/473.npy already exists..
# File ./dataset/new_preprocessed-data/val/474.npy already exists..
# File ./dataset/new_preprocessed-data/train/475.npy already exists..
# File ./dataset/new_preprocessed-data/val/476.npy already exists..
# File ./dataset/new_preprocessed-data/train/477.npy already exists..
# File ./dataset/new_preprocessed-data/test/478.npy already exists..
# File ./dataset/new_preprocessed-data/val/479.npy already exists..
# File ./dataset/new_preprocessed-data/val/480.npy already exists..
# File ./dataset/new_preprocessed-data/train/481.npy already exists..
# File ./dataset/new_preprocessed-data/train/482.npy already exists..
# File ./dataset/new_preprocessed-data/train/483.npy already exists..
# File ./dataset/new_preprocessed-data/train/484.npy already exists..
# File ./dataset/new_preprocessed-data/train/485.npy already exists..
# File ./dataset/new_preprocessed-data/val/486.npy already exists..
# File ./dataset/new_preprocessed-data/train/487.npy already exists..
# File ./dataset/new_preprocessed-data/train/488.npy already exists..
# File ./dataset/new_preprocessed-data/train/489.npy already exists..
# File ./dataset/new_preprocessed-data/train/490.npy already exists..
# File ./dataset/new_preprocessed-data/train/491.npy already exists..
# File ./dataset/new_preprocessed-data/train/492.npy already exists..
# File ./dataset/new_preprocessed-data/test/493.npy already exists..
# File ./dataset/new_preprocessed-data/train/494.npy already exists..
# File ./dataset/new_preprocessed-data/test/495.npy already exists..
# File ./dataset/new_preprocessed-data/train/496.npy already exists..
# File ./dataset/new_preprocessed-data/train/497.npy already exists..
# File ./dataset/new_preprocessed-data/train/498.npy already exists..
# File ./dataset/new_preprocessed-data/train/499.npy already exists..
# File ./dataset/new_preprocessed-data/train/500.npy already exists..
# File ./dataset/new_preprocessed-data/test/501.npy already exists..
# File ./dataset/new_preprocessed-data/train/502.npy already exists..
# File ./dataset/new_preprocessed-data/train/503.npy already exists..
# File ./dataset/new_preprocessed-data/val/504.npy already exists..
# File ./dataset/new_preprocessed-data/train/505.npy already exists..
# File ./dataset/new_preprocessed-data/train/506.npy already exists..
# File ./dataset/new_preprocessed-data/test/507.npy already exists..
# File ./dataset/new_preprocessed-data/train/508.npy already exists..
# File ./dataset/new_preprocessed-data/train/509.npy already exists..
# File ./dataset/new_preprocessed-data/train/510.npy already exists..
# File ./dataset/new_preprocessed-data/val/511.npy already exists..
# File ./dataset/new_preprocessed-data/train/512.npy already exists..
# File ./dataset/new_preprocessed-data/val/513.npy already exists..
# File ./dataset/new_preprocessed-data/train/514.npy already exists..
# File ./dataset/new_preprocessed-data/test/515.npy already exists..
# File ./dataset/new_preprocessed-data/train/516.npy already exists..
# File ./dataset/new_preprocessed-data/val/517.npy already exists..
# File ./dataset/new_preprocessed-data/train/518.npy already exists..
# File ./dataset/new_preprocessed-data/train/519.npy already exists..
# File ./dataset/new_preprocessed-data/test/520.npy already exists..
# File ./dataset/new_preprocessed-data/test/521.npy already exists..
# File ./dataset/new_preprocessed-data/train/522.npy already exists..
# File ./dataset/new_preprocessed-data/train/523.npy already exists..
# File ./dataset/new_preprocessed-data/train/524.npy already exists..
# File ./dataset/new_preprocessed-data/val/525.npy already exists..
# File ./dataset/new_preprocessed-data/train/526.npy already exists..
# File ./dataset/new_preprocessed-data/test/527.npy already exists..
# File ./dataset/new_preprocessed-data/train/528.npy already exists..
# File ./dataset/new_preprocessed-data/val/529.npy already exists..
# File ./dataset/new_preprocessed-data/val/530.npy already exists..
# File ./dataset/new_preprocessed-data/train/531.npy already exists..
# File ./dataset/new_preprocessed-data/train/532.npy already exists..
# File ./dataset/new_preprocessed-data/train/533.npy already exists..
# File ./dataset/new_preprocessed-data/train/534.npy already exists..
# File ./dataset/new_preprocessed-data/train/535.npy already exists..
# File ./dataset/new_preprocessed-data/val/536.npy already exists..
# File ./dataset/new_preprocessed-data/train/537.npy already exists..
# File ./dataset/new_preprocessed-data/train/538.npy already exists..
# File ./dataset/new_preprocessed-data/train/539.npy already exists..
# File ./dataset/new_preprocessed-data/train/540.npy already exists..
# File ./dataset/new_preprocessed-data/test/541.npy already exists..
# File ./dataset/new_preprocessed-data/val/542.npy already exists..
# File ./dataset/new_preprocessed-data/val/543.npy already exists..
# File ./dataset/new_preprocessed-data/train/544.npy already exists..
# File ./dataset/new_preprocessed-data/train/545.npy already exists..
# File ./dataset/new_preprocessed-data/train/546.npy already exists..
# File ./dataset/new_preprocessed-data/train/547.npy already exists..
# File ./dataset/new_preprocessed-data/train/548.npy already exists..
# File ./dataset/new_preprocessed-data/val/549.npy already exists..
# File ./dataset/new_preprocessed-data/train/550.npy already exists..
# File ./dataset/new_preprocessed-data/train/551.npy already exists..
# File ./dataset/new_preprocessed-data/train/552.npy already exists..
# File ./dataset/new_preprocessed-data/train/553.npy already exists..
# File ./dataset/new_preprocessed-data/train/554.npy already exists..
# File ./dataset/new_preprocessed-data/train/555.npy already exists..
# File ./dataset/new_preprocessed-data/test/556.npy already exists..
# File ./dataset/new_preprocessed-data/train/557.npy already exists..
# File ./dataset/new_preprocessed-data/test/558.npy already exists..
# File ./dataset/new_preprocessed-data/train/559.npy already exists..
# File ./dataset/new_preprocessed-data/train/560.npy already exists..
# File ./dataset/new_preprocessed-data/train/561.npy already exists..
# File ./dataset/new_preprocessed-data/test/562.npy already exists..
# File ./dataset/new_preprocessed-data/train/563.npy already exists..
# File ./dataset/new_preprocessed-data/test/564.npy already exists..
# File ./dataset/new_preprocessed-data/train/565.npy already exists..
# File ./dataset/new_preprocessed-data/train/566.npy already exists..
# File ./dataset/new_preprocessed-data/train/567.npy already exists..
# File ./dataset/new_preprocessed-data/test/568.npy already exists..
# File ./dataset/new_preprocessed-data/val/569.npy already exists..
# File ./dataset/new_preprocessed-data/train/570.npy already exists..
# File ./dataset/new_preprocessed-data/val/571.npy already exists..
# File ./dataset/new_preprocessed-data/val/572.npy already exists..
# File ./dataset/new_preprocessed-data/train/573.npy already exists..
# File ./dataset/new_preprocessed-data/train/574.npy already exists..
# File ./dataset/new_preprocessed-data/train/575.npy already exists..
# File ./dataset/new_preprocessed-data/train/576.npy already exists..
# File ./dataset/new_preprocessed-data/train/577.npy already exists..
# File ./dataset/new_preprocessed-data/val/578.npy already exists..
# File ./dataset/new_preprocessed-data/train/579.npy already exists..
# File ./dataset/new_preprocessed-data/train/580.npy already exists..
# File ./dataset/new_preprocessed-data/train/581.npy already exists..
# File ./dataset/new_preprocessed-data/train/582.npy already exists..
# File ./dataset/new_preprocessed-data/test/583.npy already exists..
# File ./dataset/new_preprocessed-data/val/584.npy already exists..
# File ./dataset/new_preprocessed-data/val/585.npy already exists..
# File ./dataset/new_preprocessed-data/train/586.npy already exists..
# File ./dataset/new_preprocessed-data/train/587.npy already exists..
# File ./dataset/new_preprocessed-data/train/588.npy already exists..
# File ./dataset/new_preprocessed-data/train/589.npy already exists..
# File ./dataset/new_preprocessed-data/train/590.npy already exists..
# File ./dataset/new_preprocessed-data/val/591.npy already exists..
# File ./dataset/new_preprocessed-data/train/592.npy already exists..
# File ./dataset/new_preprocessed-data/train/593.npy already exists..
# File ./dataset/new_preprocessed-data/train/594.npy already exists..
# File ./dataset/new_preprocessed-data/train/595.npy already exists..
# File ./dataset/new_preprocessed-data/train/596.npy already exists..
# File ./dataset/new_preprocessed-data/train/597.npy already exists..
# File ./dataset/new_preprocessed-data/test/598.npy already exists..
# File ./dataset/new_preprocessed-data/train/599.npy already exists..
# File ./dataset/new_preprocessed-data/test/600.npy already exists..
# File ./dataset/new_preprocessed-data/train/601.npy already exists..
# File ./dataset/new_preprocessed-data/train/602.npy already exists..
# File ./dataset/new_preprocessed-data/train/603.npy already exists..
# File ./dataset/new_preprocessed-data/test/604.npy already exists..
# File ./dataset/new_preprocessed-data/val/605.npy already exists..
# File ./dataset/new_preprocessed-data/val/606.npy already exists..
# File ./dataset/new_preprocessed-data/train/607.npy already exists..
# File ./dataset/new_preprocessed-data/train/608.npy already exists..
# File ./dataset/new_preprocessed-data/train/609.npy already exists..
# File ./dataset/new_preprocessed-data/train/610.npy already exists..
# File ./dataset/new_preprocessed-data/train/611.npy already exists..
# File ./dataset/new_preprocessed-data/val/612.npy already exists..
# File ./dataset/new_preprocessed-data/train/613.npy already exists..
# File ./dataset/new_preprocessed-data/train/614.npy already exists..
# File ./dataset/new_preprocessed-data/train/615.npy already exists..
# File ./dataset/new_preprocessed-data/train/616.npy already exists..
# File ./dataset/new_preprocessed-data/train/617.npy already exists..
# File ./dataset/new_preprocessed-data/train/618.npy already exists..
# File ./dataset/new_preprocessed-data/test/619.npy already exists..
# File ./dataset/new_preprocessed-data/train/620.npy already exists..
# File ./dataset/new_preprocessed-data/test/621.npy already exists..
# File ./dataset/new_preprocessed-data/train/622.npy already exists..
# File ./dataset/new_preprocessed-data/train/623.npy already exists..
# File ./dataset/new_preprocessed-data/train/624.npy already exists..
# File ./dataset/new_preprocessed-data/test/625.npy already exists..
# File ./dataset/new_preprocessed-data/val/626.npy already exists..
# File ./dataset/new_preprocessed-data/val/627.npy already exists..
#   4%|██▏                                                      | 788/21083 [00:00<00:14, 1442.09it/s]
# File ./dataset/new_preprocessed-data/train/628.npy already exists..
# File ./dataset/new_preprocessed-data/train/629.npy already exists..
# File ./dataset/new_preprocessed-data/train/630.npy already exists..
# File ./dataset/new_preprocessed-data/train/631.npy already exists..
# File ./dataset/new_preprocessed-data/train/632.npy already exists..
# File ./dataset/new_preprocessed-data/val/633.npy already exists..
# File ./dataset/new_preprocessed-data/train/634.npy already exists..
# File ./dataset/new_preprocessed-data/train/635.npy already exists..
# File ./dataset/new_preprocessed-data/train/636.npy already exists..
# File ./dataset/new_preprocessed-data/train/637.npy already exists..
# File ./dataset/new_preprocessed-data/train/638.npy already exists..
# File ./dataset/new_preprocessed-data/train/639.npy already exists..
# File ./dataset/new_preprocessed-data/test/640.npy already exists..
# File ./dataset/new_preprocessed-data/train/641.npy already exists..
# File ./dataset/new_preprocessed-data/test/642.npy already exists..
# File ./dataset/new_preprocessed-data/train/643.npy already exists..
# File ./dataset/new_preprocessed-data/train/644.npy already exists..
# File ./dataset/new_preprocessed-data/train/645.npy already exists..
# File ./dataset/new_preprocessed-data/test/646.npy already exists..
# File ./dataset/new_preprocessed-data/val/647.npy already exists..
# File ./dataset/new_preprocessed-data/val/648.npy already exists..
# File ./dataset/new_preprocessed-data/train/649.npy already exists..
# File ./dataset/new_preprocessed-data/train/650.npy already exists..
# File ./dataset/new_preprocessed-data/train/651.npy already exists..
# File ./dataset/new_preprocessed-data/train/652.npy already exists..
# File ./dataset/new_preprocessed-data/train/653.npy already exists..
# File ./dataset/new_preprocessed-data/val/654.npy already exists..
# File ./dataset/new_preprocessed-data/train/655.npy already exists..
# File ./dataset/new_preprocessed-data/train/656.npy already exists..
# File ./dataset/new_preprocessed-data/train/657.npy already exists..
# File ./dataset/new_preprocessed-data/train/658.npy already exists..
# File ./dataset/new_preprocessed-data/train/659.npy already exists..
# File ./dataset/new_preprocessed-data/train/660.npy already exists..
# File ./dataset/new_preprocessed-data/test/661.npy already exists..
# File ./dataset/new_preprocessed-data/train/662.npy already exists..
# File ./dataset/new_preprocessed-data/test/663.npy already exists..
# File ./dataset/new_preprocessed-data/train/664.npy already exists..
# File ./dataset/new_preprocessed-data/train/665.npy already exists..
# File ./dataset/new_preprocessed-data/train/666.npy already exists..
# File ./dataset/new_preprocessed-data/test/667.npy already exists..
# File ./dataset/new_preprocessed-data/val/668.npy already exists..
# File ./dataset/new_preprocessed-data/val/669.npy already exists..
# File ./dataset/new_preprocessed-data/train/670.npy already exists..
# File ./dataset/new_preprocessed-data/train/671.npy already exists..
# File ./dataset/new_preprocessed-data/train/672.npy already exists..
# File ./dataset/new_preprocessed-data/train/673.npy already exists..
# File ./dataset/new_preprocessed-data/train/674.npy already exists..
# File ./dataset/new_preprocessed-data/val/675.npy already exists..
# File ./dataset/new_preprocessed-data/train/676.npy already exists..
# File ./dataset/new_preprocessed-data/train/677.npy already exists..
# File ./dataset/new_preprocessed-data/train/678.npy already exists..
# File ./dataset/new_preprocessed-data/train/679.npy already exists..
# File ./dataset/new_preprocessed-data/train/680.npy already exists..
# File ./dataset/new_preprocessed-data/train/681.npy already exists..
# File ./dataset/new_preprocessed-data/test/682.npy already exists..
# File ./dataset/new_preprocessed-data/train/683.npy already exists..
# File ./dataset/new_preprocessed-data/test/684.npy already exists..
# File ./dataset/new_preprocessed-data/train/685.npy already exists..
# File ./dataset/new_preprocessed-data/train/686.npy already exists..
# File ./dataset/new_preprocessed-data/train/687.npy already exists..
# File ./dataset/new_preprocessed-data/train/688.npy already exists..
# File ./dataset/new_preprocessed-data/train/689.npy already exists..
# File ./dataset/new_preprocessed-data/test/690.npy already exists..
# File ./dataset/new_preprocessed-data/val/691.npy already exists..
# File ./dataset/new_preprocessed-data/train/692.npy already exists..
# File ./dataset/new_preprocessed-data/val/693.npy already exists..
# File ./dataset/new_preprocessed-data/train/694.npy already exists..
# File ./dataset/new_preprocessed-data/train/695.npy already exists..
# File ./dataset/new_preprocessed-data/train/696.npy already exists..
# File ./dataset/new_preprocessed-data/train/697.npy already exists..
# File ./dataset/new_preprocessed-data/train/698.npy already exists..
# File ./dataset/new_preprocessed-data/train/699.npy already exists..
# File ./dataset/new_preprocessed-data/train/700.npy already exists..
# File ./dataset/new_preprocessed-data/train/701.npy already exists..
# File ./dataset/new_preprocessed-data/test/702.npy already exists..
# File ./dataset/new_preprocessed-data/train/703.npy already exists..
# File ./dataset/new_preprocessed-data/val/704.npy already exists..
# File ./dataset/new_preprocessed-data/test/705.npy already exists..
# File ./dataset/new_preprocessed-data/train/706.npy already exists..
# ...
# File ./dataset/new_preprocessed-data/train/20854.npy already exists..
# File ./dataset/new_preprocessed-data/train/20855.npy already exists..
# File ./dataset/new_preprocessed-data/train/20856.npy already exists..
# File ./dataset/new_preprocessed-data/train/20857.npy already exists..
# File ./dataset/new_preprocessed-data/train/20858.npy already exists..
# File ./dataset/new_preprocessed-data/test/20859.npy already exists..
# File ./dataset/new_preprocessed-data/val/20860.npy already exists..
# File ./dataset/new_preprocessed-data/train/20861.npy already exists..
# File ./dataset/new_preprocessed-data/train/20862.npy already exists..
# File ./dataset/new_preprocessed-data/train/20863.npy already exists..
# File ./dataset/new_preprocessed-data/train/20864.npy already exists..
# File ./dataset/new_preprocessed-data/train/20865.npy already exists..
# File ./dataset/new_preprocessed-data/test/20866.npy already exists..
# File ./dataset/new_preprocessed-data/val/20867.npy already exists..
# File ./dataset/new_preprocessed-data/train/20868.npy already exists..
# File ./dataset/new_preprocessed-data/train/20869.npy already exists..
# File ./dataset/new_preprocessed-data/train/20870.npy already exists..
# File ./dataset/new_preprocessed-data/train/20871.npy already exists..
# File ./dataset/new_preprocessed-data/train/20872.npy already exists..
# File ./dataset/new_preprocessed-data/test/20873.npy already exists..
# File ./dataset/new_preprocessed-data/val/20874.npy already exists..
# File ./dataset/new_preprocessed-data/train/20875.npy already exists..
# File ./dataset/new_preprocessed-data/train/20876.npy already exists..
# File ./dataset/new_preprocessed-data/train/20877.npy already exists..
# File ./dataset/new_preprocessed-data/train/20878.npy already exists..
# File ./dataset/new_preprocessed-data/train/20879.npy already exists..
# File ./dataset/new_preprocessed-data/test/20880.npy already exists..
# File ./dataset/new_preprocessed-data/val/20881.npy already exists..
# File ./dataset/new_preprocessed-data/train/20882.npy already exists..
# File ./dataset/new_preprocessed-data/train/20883.npy already exists..
# File ./dataset/new_preprocessed-data/train/20884.npy already exists..
# File ./dataset/new_preprocessed-data/train/20885.npy already exists..
# File ./dataset/new_preprocessed-data/train/20886.npy already exists..
# File ./dataset/new_preprocessed-data/test/20887.npy already exists..
# File ./dataset/new_preprocessed-data/val/20888.npy already exists..
# File ./dataset/new_preprocessed-data/train/20889.npy already exists..
# File ./dataset/new_preprocessed-data/train/20890.npy already exists..
# File ./dataset/new_preprocessed-data/train/20891.npy already exists..
# File ./dataset/new_preprocessed-data/train/20892.npy already exists..
# File ./dataset/new_preprocessed-data/train/20893.npy already exists..
# File ./dataset/new_preprocessed-data/test/20894.npy already exists..
# File ./dataset/new_preprocessed-data/val/20895.npy already exists..
# File ./dataset/new_preprocessed-data/train/20896.npy already exists..
# File ./dataset/new_preprocessed-data/train/20897.npy already exists..
# File ./dataset/new_preprocessed-data/train/20898.npy already exists..
# File ./dataset/new_preprocessed-data/train/20899.npy already exists..
# File ./dataset/new_preprocessed-data/train/20900.npy already exists..
# File ./dataset/new_preprocessed-data/test/20901.npy already exists..
# File ./dataset/new_preprocessed-data/val/20902.npy already exists..
# File ./dataset/new_preprocessed-data/train/20903.npy already exists..
# File ./dataset/new_preprocessed-data/train/20904.npy already exists..
# File ./dataset/new_preprocessed-data/train/20905.npy already exists..
# File ./dataset/new_preprocessed-data/train/20906.npy already exists..
# File ./dataset/new_preprocessed-data/train/20907.npy already exists..
# File ./dataset/new_preprocessed-data/test/20908.npy already exists..
# File ./dataset/new_preprocessed-data/val/20909.npy already exists..
# File ./dataset/new_preprocessed-data/train/20910.npy already exists..
# File ./dataset/new_preprocessed-data/train/20911.npy already exists..
# File ./dataset/new_preprocessed-data/train/20912.npy already exists..
# File ./dataset/new_preprocessed-data/train/20913.npy already exists..
# File ./dataset/new_preprocessed-data/train/20914.npy already exists..
# File ./dataset/new_preprocessed-data/test/20915.npy already exists..
# File ./dataset/new_preprocessed-data/val/20916.npy already exists..
# File ./dataset/new_preprocessed-data/train/20917.npy already exists..
# File ./dataset/new_preprocessed-data/train/20918.npy already exists..
# File ./dataset/new_preprocessed-data/train/20919.npy already exists..
# File ./dataset/new_preprocessed-data/train/20920.npy already exists..
# File ./dataset/new_preprocessed-data/train/20921.npy already exists..
# File ./dataset/new_preprocessed-data/test/20922.npy already exists..
# File ./dataset/new_preprocessed-data/val/20923.npy already exists..
# File ./dataset/new_preprocessed-data/train/20924.npy already exists..
# File ./dataset/new_preprocessed-data/train/20925.npy already exists..
# File ./dataset/new_preprocessed-data/train/20926.npy already exists..
# File ./dataset/new_preprocessed-data/train/20927.npy already exists..
# File ./dataset/new_preprocessed-data/train/20928.npy already exists..
# File ./dataset/new_preprocessed-data/test/20929.npy already exists..
# File ./dataset/new_preprocessed-data/val/20930.npy already exists..
# File ./dataset/new_preprocessed-data/train/20931.npy already exists..
# File ./dataset/new_preprocessed-data/train/20932.npy already exists..
# File ./dataset/new_preprocessed-data/train/20933.npy already exists..
# File ./dataset/new_preprocessed-data/train/20934.npy already exists..
# File ./dataset/new_preprocessed-data/train/20935.npy already exists..
# File ./dataset/new_preprocessed-data/test/20936.npy already exists..
# File ./dataset/new_preprocessed-data/val/20937.npy already exists..
# File ./dataset/new_preprocessed-data/train/20938.npy already exists..
# File ./dataset/new_preprocessed-data/train/20939.npy already exists..
# File ./dataset/new_preprocessed-data/train/20940.npy already exists..
# File ./dataset/new_preprocessed-data/train/20941.npy already exists..
# File ./dataset/new_preprocessed-data/train/20942.npy already exists..
# File ./dataset/new_preprocessed-data/test/20943.npy already exists..
# File ./dataset/new_preprocessed-data/val/20944.npy already exists..
# File ./dataset/new_preprocessed-data/train/20945.npy already exists..
# File ./dataset/new_preprocessed-data/train/20946.npy already exists..
# File ./dataset/new_preprocessed-data/train/20947.npy already exists..
# File ./dataset/new_preprocessed-data/train/20948.npy already exists..
# File ./dataset/new_preprocessed-data/train/20949.npy already exists..
# File ./dataset/new_preprocessed-data/test/20950.npy already exists..
# File ./dataset/new_preprocessed-data/val/20951.npy already exists..
# File ./dataset/new_preprocessed-data/train/20952.npy already exists..
# File ./dataset/new_preprocessed-data/train/20953.npy already exists..
# File ./dataset/new_preprocessed-data/train/20954.npy already exists..
# File ./dataset/new_preprocessed-data/train/20955.npy already exists..
# File ./dataset/new_preprocessed-data/train/20956.npy already exists..
# File ./dataset/new_preprocessed-data/test/20957.npy already exists..
# File ./dataset/new_preprocessed-data/val/20958.npy already exists..
# File ./dataset/new_preprocessed-data/train/20959.npy already exists..
# File ./dataset/new_preprocessed-data/train/20960.npy already exists..
# File ./dataset/new_preprocessed-data/train/20961.npy already exists..
# File ./dataset/new_preprocessed-data/train/20962.npy already exists..
# File ./dataset/new_preprocessed-data/train/20963.npy already exists..
# File ./dataset/new_preprocessed-data/test/20964.npy already exists..
# File ./dataset/new_preprocessed-data/val/20965.npy already exists..
# File ./dataset/new_preprocessed-data/train/20966.npy already exists..
# File ./dataset/new_preprocessed-data/train/20967.npy already exists..
# File ./dataset/new_preprocessed-data/train/20968.npy already exists..
# File ./dataset/new_preprocessed-data/train/20969.npy already exists..
# File ./dataset/new_preprocessed-data/train/20970.npy already exists..
# File ./dataset/new_preprocessed-data/test/20971.npy already exists..
# File ./dataset/new_preprocessed-data/val/20972.npy already exists..
# File ./dataset/new_preprocessed-data/train/20973.npy already exists..
# File ./dataset/new_preprocessed-data/train/20974.npy already exists..
# File ./dataset/new_preprocessed-data/train/20975.npy already exists..
# File ./dataset/new_preprocessed-data/train/20976.npy already exists..
# File ./dataset/new_preprocessed-data/train/20977.npy already exists..
# File ./dataset/new_preprocessed-data/test/20978.npy already exists..
# File ./dataset/new_preprocessed-data/val/20979.npy already exists..
# File ./dataset/new_preprocessed-data/train/20980.npy already exists..
# File ./dataset/new_preprocessed-data/train/20981.npy already exists..
# File ./dataset/new_preprocessed-data/train/20982.npy already exists..
# File ./dataset/new_preprocessed-data/train/20983.npy already exists..
# File ./dataset/new_preprocessed-data/train/20984.npy already exists..
# File ./dataset/new_preprocessed-data/test/20985.npy already exists..
# File ./dataset/new_preprocessed-data/val/20986.npy already exists..
# File ./dataset/new_preprocessed-data/train/20987.npy already exists..
# File ./dataset/new_preprocessed-data/train/20988.npy already exists..
# File ./dataset/new_preprocessed-data/train/20989.npy already exists..
# File ./dataset/new_preprocessed-data/train/20990.npy already exists..
# File ./dataset/new_preprocessed-data/train/20991.npy already exists..
# File ./dataset/new_preprocessed-data/test/20992.npy already exists..
# File ./dataset/new_preprocessed-data/val/20993.npy already exists..
# File ./dataset/new_preprocessed-data/train/20994.npy already exists..
# File ./dataset/new_preprocessed-data/train/20995.npy already exists..
# File ./dataset/new_preprocessed-data/train/20996.npy already exists..
# File ./dataset/new_preprocessed-data/train/20997.npy already exists..
# File ./dataset/new_preprocessed-data/train/20998.npy already exists..
# File ./dataset/new_preprocessed-data/test/20999.npy already exists..
# File ./dataset/new_preprocessed-data/val/21000.npy already exists..
# File ./dataset/new_preprocessed-data/train/21001.npy already exists..
# File ./dataset/new_preprocessed-data/train/21002.npy already exists..
# File ./dataset/new_preprocessed-data/train/21003.npy already exists..
# File ./dataset/new_preprocessed-data/train/21004.npy already exists..
# File ./dataset/new_preprocessed-data/train/21005.npy already exists..
# File ./dataset/new_preprocessed-data/test/21006.npy already exists..
# File ./dataset/new_preprocessed-data/val/21007.npy already exists..
# File ./dataset/new_preprocessed-data/train/21008.npy already exists..
# File ./dataset/new_preprocessed-data/train/21009.npy already exists..
# File ./dataset/new_preprocessed-data/train/21010.npy already exists..
# File ./dataset/new_preprocessed-data/train/21011.npy already exists..
# File ./dataset/new_preprocessed-data/train/21012.npy already exists..
# File ./dataset/new_preprocessed-data/test/21013.npy already exists..
# File ./dataset/new_preprocessed-data/val/21014.npy already exists..
# File ./dataset/new_preprocessed-data/train/21015.npy already exists..
# File ./dataset/new_preprocessed-data/train/21016.npy already exists..
# File ./dataset/new_preprocessed-data/train/21017.npy already exists..
# File ./dataset/new_preprocessed-data/train/21018.npy already exists..
# File ./dataset/new_preprocessed-data/train/21019.npy already exists..
# File ./dataset/new_preprocessed-data/test/21020.npy already exists..
# File ./dataset/new_preprocessed-data/val/21021.npy already exists..
# File ./dataset/new_preprocessed-data/train/21022.npy already exists..
# File ./dataset/new_preprocessed-data/train/21023.npy already exists..
# File ./dataset/new_preprocessed-data/train/21024.npy already exists..
# File ./dataset/new_preprocessed-data/train/21025.npy already exists..
# File ./dataset/new_preprocessed-data/train/21026.npy already exists..
# File ./dataset/new_preprocessed-data/test/21027.npy already exists..
# File ./dataset/new_preprocessed-data/val/21028.npy already exists..
# File ./dataset/new_preprocessed-data/train/21029.npy already exists..
# File ./dataset/new_preprocessed-data/train/21030.npy already exists..
# File ./dataset/new_preprocessed-data/train/21031.npy already exists..
# File ./dataset/new_preprocessed-data/train/21032.npy already exists..
# File ./dataset/new_preprocessed-data/train/21033.npy already exists..
# File ./dataset/new_preprocessed-data/test/21034.npy already exists..
# File ./dataset/new_preprocessed-data/val/21035.npy already exists..
# File ./dataset/new_preprocessed-data/train/21036.npy already exists..
# File ./dataset/new_preprocessed-data/train/21037.npy already exists..
# File ./dataset/new_preprocessed-data/train/21038.npy already exists..
# File ./dataset/new_preprocessed-data/train/21039.npy already exists..
# File ./dataset/new_preprocessed-data/train/21040.npy already exists..
# File ./dataset/new_preprocessed-data/test/21041.npy already exists..
# File ./dataset/new_preprocessed-data/val/21042.npy already exists..
# File ./dataset/new_preprocessed-data/train/21043.npy already exists..
# File ./dataset/new_preprocessed-data/train/21044.npy already exists..
# File ./dataset/new_preprocessed-data/train/21045.npy already exists..
# File ./dataset/new_preprocessed-data/train/21046.npy already exists..
# File ./dataset/new_preprocessed-data/train/21047.npy already exists..
# File ./dataset/new_preprocessed-data/test/21048.npy already exists..
# File ./dataset/new_preprocessed-data/val/21049.npy already exists..
# File ./dataset/new_preprocessed-data/train/21050.npy already exists..
# File ./dataset/new_preprocessed-data/train/21051.npy already exists..
# File ./dataset/new_preprocessed-data/train/21052.npy already exists..
# File ./dataset/new_preprocessed-data/train/21053.npy already exists..
# File ./dataset/new_preprocessed-data/train/21054.npy already exists..
# File ./dataset/new_preprocessed-data/test/21055.npy already exists..
# File ./dataset/new_preprocessed-data/val/21056.npy already exists..
# File ./dataset/new_preprocessed-data/train/21057.npy already exists..
# File ./dataset/new_preprocessed-data/train/21058.npy already exists..
# File ./dataset/new_preprocessed-data/train/21059.npy already exists..
# File ./dataset/new_preprocessed-data/train/21060.npy already exists..
# File ./dataset/new_preprocessed-data/train/21061.npy already exists..
# File ./dataset/new_preprocessed-data/test/21062.npy already exists..
# File ./dataset/new_preprocessed-data/val/21063.npy already exists..
# File ./dataset/new_preprocessed-data/train/21064.npy already exists..
# File ./dataset/new_preprocessed-data/train/21065.npy already exists..
# File ./dataset/new_preprocessed-data/train/21066.npy already exists..
# File ./dataset/new_preprocessed-data/train/21067.npy already exists..
# File ./dataset/new_preprocessed-data/train/21068.npy already exists..
# File ./dataset/new_preprocessed-data/test/21069.npy already exists..
# File ./dataset/new_preprocessed-data/val/21070.npy already exists..
# File ./dataset/new_preprocessed-data/train/21071.npy already exists..
# File ./dataset/new_preprocessed-data/train/21072.npy already exists..
# File ./dataset/new_preprocessed-data/train/21073.npy already exists..
# File ./dataset/new_preprocessed-data/train/21074.npy already exists..
# File ./dataset/new_preprocessed-data/train/21075.npy already exists..
# File ./dataset/new_preprocessed-data/test/21076.npy already exists..
# File ./dataset/new_preprocessed-data/val/21077.npy already exists..
# File ./dataset/new_preprocessed-data/train/21078.npy already exists..
# File ./dataset/new_preprocessed-data/train/21079.npy already exists..
# File ./dataset/new_preprocessed-data/train/21080.npy already exists..
# File ./dataset/new_preprocessed-data/train/21081.npy already exists..
# File ./dataset/new_preprocessed-data/train/21082.npy already exists..

# %% [markdown]
# ### Storing Landmarks According to Split

# %% [markdown]
# Three **.npz** files for train, test and validation data are created. These files is used later to obtain the landmark data without performing the process every time, thus saving time.
#
# The function `generate_npz` takes in a directory path for the npy filepath, a dictionary and the path to save the compressed npz file. Next, each saved numpy array of that particular split is loaded and added to the dictionary. Finally, the dictionary is saved as a compressed npz file.
#
# `generate_npz` is used for storing training, testing and validation data if the npz does not exist. This saves time by using the previously existing npz file instead of generating each time.
#
# Next the dictionary are deleted and garbage collector is called to free up memory space.

# %%
train_landmarks_dict = {}
test_landmarks_dict = {}
val_landmarks_dict = {}

train_npy_dir = main_path + 'new_preprocessed-data/train'
test_npy_dir = main_path + 'new_preprocessed-data/test'
val_npy_dir = main_path + 'new_preprocessed-data/val'

# %%
# compressed form of landmark files saved
def generate_npz(npy_dir, landmarks_dict, npz_path):
    for filename in os.listdir(npy_dir):
        if filename.endswith('.npy'):
            key = filename.split('.')[0]
            landmarks = np.load(os.path.join(
                npy_dir, filename), allow_pickle=True) # to allow serializing objects
            # print(landmarks)
            landmarks_dict[key] = landmarks
            print(f'{npy_dir}/{filename} added')

    np.savez_compressed(npz_path, **landmarks_dict)
    print(f"{npy_dir} saved successfully")

# %%
npz_landmarks_dir = main_path + 'landmarks/'
if not os.path.exists(npz_landmarks_dir):
    os.mkdir(npz_landmarks_dir)

# %%
npz_train_path = main_path + 'landmarks/landmarks_train.npz'
npz_test_path = main_path + 'landmarks/landmarks_test.npz'
npz_val_path = main_path + 'landmarks/landmarks_val.npz'

if not os.path.exists(npz_train_path):
    generate_npz(train_npy_dir, train_landmarks_dict, npz_train_path)
if not os.path.exists(npz_test_path):
    generate_npz(test_npy_dir, test_landmarks_dict, npz_test_path)
if not os.path.exists(npz_val_path):
    generate_npz(val_npy_dir, val_landmarks_dict, npz_val_path)

# %%
del train_landmarks_dict, test_landmarks_dict, val_landmarks_dict
gc.collect()
# Out:
# 9

# %% [markdown]
# # Data Loading

# %% [markdown]
# This section loads the preprocessed landmarks from the saved compressed npz into `X_train`, `Y_train`, `X_val`, `Y_val`, `X_test` and `Y_test` variables to be used in the model later on.
#
# `load_data` function is used to load data based on a number of choices. It takes in parameters of filtered labels, a number of labels from the top and a landmark dictionary. The above function is used to load train, validation and test data with a specific number of labels and the loaded landmarks are passed as landmark dictionary.
#
# Next some print statements are written to check the dimensions of the data and finally, variables no longer required are deleted.

# %%
landmark_train_dict = np.load(
    npz_landmarks_dir + 'landmarks_train.npz', allow_pickle=True)
landmark_test_dict = np.load(
    npz_landmarks_dir + 'landmarks_test.npz', allow_pickle=True)
landmark_val_dict = np.load(
    npz_landmarks_dir + 'landmarks_val.npz', allow_pickle=True)

# %%
def load_data(filtered_labels=None, max_labels=None, landmarks_dict=None):

    if filtered_labels is not None:
        X = [landmarks_dict[k] for k in landmarks_dict.keys()
             if gloss_list[int(k)] in filtered_labels]
        Y = [gloss_list[int(k)] for k in landmarks_dict.keys()
             if gloss_list[int(k)] in filtered_labels]
    
    elif max_labels is not None:
        label_counts = {}
        for label in gloss_list:
            label_counts[label] = label_counts.get(label, 0) + 1 # updating label_counts with the count of occurrences for the current label

        top_labels = sorted(label_counts, key=label_counts.get, reverse=True)[:max_labels]
        X = [landmarks_dict[k] for k in landmarks_dict.keys()
             if gloss_list[int(k)] in top_labels]
        Y = [gloss_list[int(k)] for k in landmarks_dict.keys() if gloss_list[int(k)] in top_labels]
        
    else:
        X = [landmarks_dict[k] for k in landmarks_dict.keys()]
        Y = [gloss_list[int(k)] for k in landmarks_dict.keys()]

    return X, Y

# %%
X_train, Y_train = load_data(landmarks_dict=landmark_train_dict, max_labels=2000)
X_val, Y_val = load_data(landmarks_dict=landmark_val_dict, max_labels=2000)
X_test, Y_test = load_data(landmarks_dict=landmark_test_dict, max_labels=2000)

# %%
len(X_train), len(X_val), len(X_test)
# Out:
# (14289, 3916, 2878)

# %%
len(np.unique(Y_train)), len(np.unique(Y_val)), len(np.unique(Y_test))
# Out:
# (2000, 2000, 1999)

# %%
# free space
del landmark_train_dict, landmark_test_dict, landmark_val_dict

gc.collect()
# Out:
# 7778

# %% [markdown]
# # Data Augmentation

# %% [markdown]
# Data Augmentation methods are employed here to the X and Y variables of train split loaded in previous section. The following augmentation functions are defined:
# - rotations: `rotate`, `rotate_x`, `rotate_y` and `rotate_z` are performed to rotate the coordinates of landmarks based on a given rotation matrix, x axis, y axis or z axis respectively.
# - scale: preserves the center and scales the data randomly
# - shift: the data is shifted either vertically or horizontally
# - mask: a random part of the landmark is masked
# - horizontal flip: the data is flipped horizontally
# - speedup: the frame is downsized by taking every 2 frames
#
# `apply_augmentations` function applies a a subset of these augmentation functions to the data and finally `augment` function applies a variable number of augmentation to the data. The number of augmentations to be applied can be controlled using this parameter. If no number is specified, then the number of augments is selected randomly.
#
# The augmentation is applied on `X_train` and `Y_train` specifying the number of augmentations to 1 due to limitations of memory that can be allocated. Finally the dimensions are printed to check if augmentation has been applied successfully.

# %% [markdown]
# ### Rotation Augmentation

# %%
# rotate according to given matrix
def rotate(data, rotation_matrix):
    frames, landmarks, _ = data.shape
    center = np.array([0.5, 0.5, 0])
    non_zero = np.argwhere(np.any(data[:, :, :2] != 0, axis=2))
    data = data.reshape(-1, 3)
    data[non_zero] -= center
    data[non_zero] = np.dot(data[non_zero], rotation_matrix.T)
    data[non_zero] += center
    data = data.reshape(frames, landmarks, 3)
    out_of_range = np.any((data[:, :, :2] < 0) | (data[:, :, :2] > 1), axis=2)
    data[out_of_range] = 0
    return data

# rotate around the z axis
def rotate_z(data):
    angle = np.random.choice([np.random.uniform(-15, -5),
                              np.random.uniform(5, 15)])
    theta = np.radians(angle)
    rotation_matrix = np.array([
        [np.cos(theta), -np.sin(theta), 0],
        [np.sin(theta), np.cos(theta), 0],
        [0, 0, 1]
    ])
    return rotate(data, rotation_matrix)

# rotate around the y axis
def rotate_y(data):
    angle = np.random.choice([np.random.uniform(-15, -5),
                              np.random.uniform(5, 15)])
    theta = np.radians(angle)
    rotation_matrix = np.array([
        [np.cos(theta), 0, np.sin(theta)],
        [0, 1, 0],
        [-np.sin(theta), 0, np.cos(theta)]
    ])
    return rotate(data, rotation_matrix)

# rotate around the x axis
def rotate_x(data):
    angle = np.random.choice([np.random.uniform(-15, -5),
                              np.random.uniform(5, 15)])
    theta = np.radians(angle)
    rotation_matrix = np.array([
        [1, 0, 0],
        [0, np.cos(theta), -np.sin(theta)],
        [0, np.sin(theta), np.cos(theta)]
    ])
    return rotate(data, rotation_matrix)

# %% [markdown]
# ### Other Augmentations

# %%
# randomly scales data between 0.8 and 1.2 while preserving center
def zoom(data):
    factor = np.random.uniform(0.8, 1.2)
    center = np.array([0.5, 0.5])
    non_zero = np.argwhere(np.any(data[:, :, :2] != 0, axis=2))
    data[non_zero[:, 0], non_zero[:, 1], :2] = (
        (data[non_zero[:, 0], non_zero[:, 1], :2] - center) * factor + center
    )
    out_of_range = np.any((data[:, :, :2] < 0) | (data[:, :, :2] > 1), axis=2)
    data[out_of_range] = 0
    return data

# randomly shifts the data horizontally and vertically by a small amount
def shift(data):
    x_shift = np.random.uniform(-0.1, 0.1)
    y_shift = np.random.uniform(-0.1, 0.1)
    non_zero = np.argwhere(np.any(data[:, :, :2] != 0, axis=2))
    data[non_zero[:, 0], non_zero[:, 1], 0] += x_shift
    data[non_zero[:, 0], non_zero[:, 1], 1] += y_shift
    out_of_range = np.any((data[:, :, :2] < 0) | (data[:, :, :2] > 1), axis=2)
    data[out_of_range] = 0
    return data


def mask(data):
    frames, landmarks, _ = data.shape
    num_hands = int(0.3 * 42) # 30% landmarks taken from one hand
    num_rest = int(0.6 * (landmarks - 42)) # 60% landmarks taken from other hand

    # boolean mask applied
    mask = np.zeros(landmarks, dtype=bool)
    indices = np.concatenate([
        np.random.choice(42, num_hands, replace=False),
        np.random.choice(landmarks - 42, num_rest, replace=False) + 42
    ])
    mask[indices] = True
    data[:, mask] = 0
    return data

# a horizontal flip
def hflip(data):
    data[:, :, 0] = 1 - data[:, :, 0]
    return data

# downsizing the frame number by taking every 2 frames
def speedup(data):
    return data[::2]

# %% [markdown]
# ### Applying the Augmentations to the Data

# %%
def apply_augmentations(data):
    aug_functions = [rotate_x, rotate_y, rotate_z,
                     zoom, shift, mask, hflip, speedup]
    np.random.shuffle(aug_functions)
    counter = 0
    for fun in aug_functions:
        if np.random.rand() < 0.5:
            data = fun(data)
            counter += 1

    # recursive call to ensure at least one augmentation applied
    if counter == 0:
        data = apply_augmentations(data)

    return data

# %%
def augment(X, Y, num=None):
    X_aug = X.copy()
    Y_aug = Y.copy()

    if num is None:
        for i in tqdm(range(len(Y)), ncols=100):
            num_aug = np.random.choice([1, 2, 3])
            for n in range(num_aug):
                X_aug.append(apply_augmentations(X[i].copy()))
                Y_aug.append(Y[i])
    elif num > 0:
        for i in tqdm(range(len(Y)), ncols=100):
            for n in range(num):
                X_aug.append(apply_augmentations(X[i].copy()))
                Y_aug.append(Y[i])

    return X_aug, Y_aug

# %%
X_train, Y_train = augment(X_train, Y_train, 1)
# Out:
# 100%|████████████████████████████████████████████████████████| 14289/14289 [01:54<00:00, 124.41it/s]

# %%
len(X_train), len(Y_train)
# Out:
# (28578, 28578)

# %%
len(X_train), len(X_train[10]), len(X_train[12][12]), len(X_train[0][0][0])
# Out:
# (28578, 41, 180, 3)

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# This section is used to apply padding to the data to ensure the number of frames in all X is equal.
#
# `padding` function pads the sequences in `X` variables for train, validation and test. It takes in the `X`, `Y`, a desired sequence length for padding and a value to use for padding. The padded X is then stored in `X_padded` and converted to numpy array.
#
# The `padding` function is applied to the input `X` and output `Y` with a specified length of 76 and a padding of -80. The value of 76 was chosen to avoid MemoryError since the arrays take up a lot of space.
#
# Print statements at the end confirms the data was indeed padded with the specified sequence.

# %%
# only X padded
def padding(X, Y, length=None, pad=0):
    if length is None:
        length = max(len(x) for x in X)

    X_padded = []
    for x in X:
        if len(x) > length:
            X_padded.append(x[:length])  # truncate if more than length
        else:
            pad_length = length - len(x)
            X_padded.append(np.pad(
                x, ((0, pad_length), (0, 0), (0, 0)),
                mode='constant', constant_values=pad
            ))

    X_padded = np.array(X_padded)
    return X_padded, Y

# %%
gc.collect()
length = 76
X_train, Y_train = padding(X_train, Y_train, length=length, pad=-80)
X_val, Y_val = padding(X_val, Y_val, length=length, pad=-80)
X_test, Y_test = padding(X_test, Y_test, length=length, pad=-80)

# %%
# (videos, frames, landmarks, coordinates)
X_train.shape, X_val.shape, X_test.shape
# Out:
# ((28578, 76, 180, 3), (3916, 76, 180, 3), (2878, 76, 180, 3))

# %% [markdown]
# # Build and Train MLP Neural Network

# %% [markdown]
# ### Label Encoding (Using One Hot Encoding)

# %%
labels = np.unique(Y_train)
unique_labels = {word: idx for idx, word in enumerate(labels)}
print(unique_labels)
# Out:
# {'a': 0, 'a lot': 1, 'abdomen': 2, 'able': 3, 'about': 4, 'above': 5, 'accent': 6, 'accept': 7, 'accident': 8, 'accomplish': 9, 'accountant': 10, 'across': 11, 'act': 12, 'action': 13, 'active': 14, 'activity': 15, 'actor': 16, 'adapt': 17, 'add': 18, 'address': 19, 'adjective': 20, 'adjust': 21, 'admire': 22, 'admit': 23, 'adopt': 24, 'adult': 25, 'advanced': 26, 'advantage': 27, 'adverb': 28, 'affect': 29, 'afraid': 30, 'africa': 31, 'after': 32, 'afternoon': 33, 'again': 34, 'against': 35, 'age': 36, 'agenda': 37, 'ago': 38, 'agree': 39, 'agreement': 40, 'ahead': 41, 'aid': 42, 'aim': 43, 'airplane': 44, 'alarm': 45, 'alcohol': 46, 'algebra': 47, 'all': 48, 'all day': 49, 'allergy': 50, 'alligator': 51, 'allow': 52, 'almost': 53, 'alone': 54, 'alphabet': 55, 'already': 56, 'also': 57, 'always': 58, 'amazing': 59, 'america': 60, 'amputate': 61, 'analyze': 62, 'anatomy': 63, 'and': 64, 'angel': 65, 'angle': 66, 'angry': 67, 'animal': 68, 'anniversary': 69, 'announce': 70, 'annoy': 71, 'another': 72, 'answer': 73, 'any': 74, 'anyway': 75, 'apart': 76, 'apartment': 77, 'apostrophe': 78, 'appear': 79, 'appetite': 80, 'apple': 81, 'appointment': 82, 'appreciate': 83, 'approach': 84, 'appropriate': 85, 'approve': 86, 'april': 87, 'archery': 88, 'area': 89, 'argue': 90, 'arizona': 91, 'arm': 92, 'army': 93, 'around': 94, 'arrest': 95, 'arrive': 96, 'arrogant': 97, 'art': 98, 'article': 99, 'artist': 100, 'asia': 101, 'ask': 102, 'asl': 103, 'assist': 104, 'assistant': 105, 'assume': 106, 'attend': 107, 'attention': 108, 'attitude': 109, 'attorney': 110, 'attract': 111, 'auction': 112, 'audience': 113, 'audiologist': 114, 'audiology': 115, 'august': 116, 'aunt': 117, 'australia': 118, 'austria': 119, 'author': 120, 'authority': 121, 'autumn': 122, 'available': 123, 'average': 124, 'avoid': 125, 'awake': 126, 'award': 127, 'aware': 128, 'away': 129, 'awful': 130, 'awkward': 131, 'b': 132, 'baby': 133, 'babysitter': 134, 'back': 135, 'background': 136, 'backpack': 137, 'bacon': 138, 'bad': 139, 'bake': 140, 'balance': 141, 'bald': 142, 'ball': 143, 'balloon': 144, 'banana': 145, 'bank': 146, 'baptize': 147, 'bar': 148, 'barely': 149, 'bark': 150, 'baseball': 151, 'basement': 152, 'basic': 153, 'basketball': 154, 'bath': 155, 'bathroom': 156, 'battery': 157, 'battle': 158, 'bear': 159, 'beard': 160, 'beautiful': 161, 'because': 162, 'become': 163, 'bed': 164, 'bedroom': 165, 'bee': 166, 'beer': 167, 'before': 168, 'beg': 169, 'beginning': 170, 'behavior': 171, 'behind': 172, 'belief': 173, 'believe': 174, 'bell': 175, 'below': 176, 'belt': 177, 'benefit': 178, 'berry': 179, 'beside': 180, 'best': 181, 'bet': 182, 'better': 183, 'between': 184, 'bible': 185, 'bicycle': 186, 'big': 187, 'bike': 188, 'binoculars': 189, 'biology': 190, 'bird': 191, 'birth': 192, 'birthday': 193, 'bite': 194, 'bitter': 195, 'black': 196, 'blame': 197, 'blanket': 198, 'blend': 199, 'bless': 200, 'blind': 201, 'blood': 202, 'blow': 203, 'blue': 204, 'boast': 205, 'boat': 206, 'body': 207, 'boil': 208, 'bone': 209, 'book': 210, 'bookshelf': 211, 'bookstore': 212, 'boots': 213, 'bored': 214, 'borrow': 215, 'boss': 216, 'both': 217, 'bother': 218, 'bottle': 219, 'bottom': 220, 'bowl': 221, 'bowling': 222, 'box': 223, 'boxing': 224, 'boy': 225, 'boyfriend': 226, 'bra': 227, 'bracelet': 228, 'brag': 229, 'braid': 230, 'brain': 231, 'brave': 232, 'bread': 233, 'break': 234, 'breakdown': 235, 'breakfast': 236, 'breathe': 237, 'breeze': 238, 'bribe': 239, 'bridge': 240, 'brief': 241, 'bright': 242, 'bring': 243, 'brochure': 244, 'broke': 245, 'brother': 246, 'brown': 247, 'brush': 248, 'buffalo': 249, 'bug': 250, 'build': 251, 'building': 252, 'bull': 253, 'bully': 254, 'burp': 255, 'bus': 256, 'bush': 257, 'business': 258, 'busy': 259, 'but': 260, 'butter': 261, 'butterfly': 262, 'button': 263, 'buy': 264, 'bye': 265, 'cabbage': 266, 'cabinet': 267, 'cafeteria': 268, 'cake': 269, 'calculate': 270, 'calculator': 271, 'calculus': 272, 'california': 273, 'call': 274, ' ...

# %%
Y_train = np.array([unique_labels[word] for word in Y_train])
Y_val = np.array([unique_labels[word] for word in Y_val])
Y_test = np.array([unique_labels[word] for word in Y_test])

# %%
Y_train = to_categorical(Y_train).astype(int)
Y_val = to_categorical(Y_val).astype(int)
Y_test = to_categorical(Y_test).astype(int)

# %%
Y_train.shape, Y_test.shape, Y_val.shape
# Out:
# ((28578, 2000), (2878, 2000), (3916, 2000))

# %% [markdown]
# ### Defining Model

# %%
tf.keras.backend.clear_session()
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    tf.config.experimental.set_memory_growth(device, True)
physical_devices
# Out:
# []

# %% [markdown]
# This is a feedforward neural network, also known as multi-layer perceptrons (MLPs) with 4 hidden layers.
# - Masking Layer at the top ignores the inputs with a value of -80 which is useful for handling padded sequences.
# - Flatten layer is used to convert the 3D output from previous layer to 1D array
# - Dense Layers of 512 units with ReLU activation are used for extracting features and to introduce non-linearity
# - Batch Normalization are applied after dense layer to normalize the activations
# - Dropout Layers after each batch normalization ensures that regulatization is applied so overfitting does not occur. The rate is set to 0.3 for two layers and 0.5 for others.
# - The final dense layer has 300 units and a linear activation. Dimension of output produced is 300.

# %%
model = tf.keras.Sequential([
    # any input equal to -80 will be masked and ignored
    tf.keras.layers.Masking(mask_value=-80, input_shape=(76, 180, 3)), # 76 frames, 180 landmarks, 3 coordinates
    tf.keras.layers.Flatten(), # convert from 3D to 1D array

    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(rate=0.3), # regularization

    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(rate=0.3), # regularization

    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(rate=0.5), # regularization

    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(rate=0.5), # regularization

    tf.keras.layers.Dense(Y_train.shape[1], activation='softmax')
])

# %% [markdown]
# **Choice of Optimizer & Loss Functions**
#
#  The choices of cosine similarity and the Adam optimizer with a learning rate schedule are common in scenarios where the goal is to capture relationships or similarities between vectors, and where adaptive learning rates and momentum can be beneficial during training.
#
#  Cosine Similarity is commonly used in tasks like word embeddings, image similarity, and, potentially, gesture recognition where the goal is to understand the similarity between different gestures.
#
#  Adam Optimizer starts with an initial learning rate of 0.001 and decays exponentially over time. This can be useful for tasks where a higher learning rate might be beneficial in the early stages of training, and a lower learning rate is useful for fine-tuning.
#
# **Callback functions**
#
# The `ModelCheckpoints` is used to save the model weights during training. It monitors the validation accuracy and the weights are only saved when the validation accuracy improves.
#
# The `EarlyStopping` callback ensures that the model training is stopped prematurely when the monitored metric, validation accuracy, stops improving. It has a patience value of 10 which is the number of epochs the model is allowed to run without any improvement in validation accuracy before the training is stopped. This prevents overfitting.

# %%
checkpoint_filepath = 'model_checkpoints/'
os.makedirs(checkpoint_filepath, exist_ok=True)

model_checkpoint = tf.keras.callbacks.ModelCheckpoint(
    filepath=os.path.join(checkpoint_filepath, 'model_{epoch:02d}.h5'),
    save_weights_only=True,
    save_best_only=True,
    monitor='val_categorical_accuracy',
    mode='max',
)

early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_categorical_accuracy',
    patience=10,
    restore_best_weights=True
)

lr_scheduler = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=0.05,
    decay_steps=1000, # decrease learning rate at an expotential rate 
    decay_rate=0.9
)

model.compile(
    loss=tf.keras.losses.CategoricalCrossentropy(),
    optimizer=tf.keras.optimizers.Adam(learning_rate=lr_scheduler), # Adaptive Moment Estimation
    metrics=['categorical_accuracy']
)

# %% [markdown]
# ### Training of Model

# %%
gc.collect()
hist = model.fit(
    X_train, Y_train,
    validation_data=(X_val, Y_val),
    epochs=100,
    batch_size=128,
    callbacks=[model_checkpoint, early_stopping]
)
# Out:
# Epoch 1/100
# 224/224 [==============================] - 113s 472ms/step - loss: 8.7853 - categorical_accuracy: 6.2986e-04 - val_loss: 18.9822 - val_categorical_accuracy: 7.6609e-04
# Epoch 2/100
# 224/224 [==============================] - 89s 398ms/step - loss: 8.8457 - categorical_accuracy: 5.5987e-04 - val_loss: 8.4700 - val_categorical_accuracy: 2.5536e-04
# Epoch 3/100
# 224/224 [==============================] - 91s 407ms/step - loss: 8.8442 - categorical_accuracy: 5.9486e-04 - val_loss: 8.0125 - val_categorical_accuracy: 0.0010
# Epoch 4/100
# 224/224 [==============================] - 92s 412ms/step - loss: 8.9542 - categorical_accuracy: 7.3483e-04 - val_loss: 11.8527 - val_categorical_accuracy: 2.5536e-04
# Epoch 5/100
# 224/224 [==============================] - 91s 406ms/step - loss: 8.9096 - categorical_accuracy: 5.2488e-04 - val_loss: 7.9637 - val_categorical_accuracy: 0.0013
# Epoch 6/100
# 224/224 [==============================] - 94s 421ms/step - loss: 8.7998 - categorical_accuracy: 4.1990e-04 - val_loss: 13.8111 - val_categorical_accuracy: 0.0023
# Epoch 7/100
# 224/224 [==============================] - 93s 416ms/step - loss: 8.5699 - categorical_accuracy: 4.5490e-04 - val_loss: 8.2412 - val_categorical_accuracy: 0.0000e+00
# Epoch 8/100
# 224/224 [==============================] - 93s 417ms/step - loss: 8.4461 - categorical_accuracy: 5.5987e-04 - val_loss: 2493.9294 - val_categorical_accuracy: 0.0010
# Epoch 9/100
# 224/224 [==============================] - 95s 425ms/step - loss: 8.3024 - categorical_accuracy: 4.5490e-04 - val_loss: 30275.7168 - val_categorical_accuracy: 0.0010
# Epoch 10/100
# 224/224 [==============================] - 92s 412ms/step - loss: 8.2588 - categorical_accuracy: 5.2488e-04 - val_loss: 61834.0469 - val_categorical_accuracy: 0.0010
# Epoch 11/100
# 224/224 [==============================] - 90s 404ms/step - loss: 8.2526 - categorical_accuracy: 3.8491e-04 - val_loss: 96084.2031 - val_categorical_accuracy: 7.6609e-04
# Epoch 12/100
# 224/224 [==============================] - 90s 403ms/step - loss: 8.2459 - categorical_accuracy: 6.6485e-04 - val_loss: 35940.0938 - val_categorical_accuracy: 7.6609e-04
# Epoch 13/100
# 224/224 [==============================] - 93s 414ms/step - loss: 8.2089 - categorical_accuracy: 6.2986e-04 - val_loss: 72477.5547 - val_categorical_accuracy: 5.1073e-04
# Epoch 14/100
# 224/224 [==============================] - 97s 434ms/step - loss: 8.2032 - categorical_accuracy: 4.8989e-04 - val_loss: 151323.5469 - val_categorical_accuracy: 5.1073e-04
# Epoch 15/100
# 224/224 [==============================] - 99s 444ms/step - loss: 8.1891 - categorical_accuracy: 6.6485e-04 - val_loss: 236236.1094 - val_categorical_accuracy: 5.1073e-04
# Epoch 16/100
# 224/224 [==============================] - 88s 393ms/step - loss: 8.2284 - categorical_accuracy: 9.7977e-04 - val_loss: 181295.2188 - val_categorical_accuracy: 5.1073e-04

# %% [markdown]
# ### Training And Validation of Model

# %%
test_loss, test_accuracy = model.evaluate(X_test, Y_test)
# Out:
# 90/90 [==============================] - 5s 48ms/step - loss: 12.7597 - categorical_accuracy: 0.0010

# %% [markdown]
# # Model Summary

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  masking (Masking)           (None, 76, 180, 3)        0
#
#  flatten (Flatten)           (None, 41040)             0
#
#  dense (Dense)               (None, 512)               21012992
#
#  batch_normalization (Batch  (None, 512)               2048
#  Normalization)
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 512)               262656
#
#  batch_normalization_1 (Bat  (None, 512)               2048
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 512)               262656
#
#  batch_normalization_2 (Bat  (None, 512)               2048
#  chNormalization)
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_3 (Dense)             (None, 512)               262656
#
#  batch_normalization_3 (Bat  (None, 512)               2048
#  chNormalization)
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  dense_4 (Dense)             (None, 2000)              1026000
#
# =================================================================
# Total params: 22835152 (87.11 MB)
# Trainable params: 22831056 (87.09 MB)
# Non-trainable params: 4096 (16.00 KB)
# _________________________________________________________________

# %% [markdown]
# ### Plotting

# %%
def plot_metric(hist, metric_name_1, metric_name_2, plot_name, y_label):

    # getting metric values using metric names as identifiers
    metric_value_1 = hist.history[metric_name_1]
    metric_value_2 = hist.history[metric_name_2]

    # creating a range object to use as x-axis (horizontal plane) of the graph.
    epochs = range(len(metric_value_1))

    # plotting.
    plt.plot(epochs, metric_value_1, 'c', label=metric_name_1)
    plt.plot(epochs, metric_value_2, 'm', label=metric_name_2)

    plt.ylabel(str(y_label))
    plt.xlabel('Epochs')

    # adding title to the plot.
    plt.title(str(plot_name))

    # adding legend to the plot.
    plt.legend()
    plt.show()

# %%
# visualizing the training and validation loss metrices
plot_metric(hist, 'loss', 'val_loss',
            'Total Loss vs Total Validation Loss', 'Loss')

# visualizing the training and validation accuracy metrices
plot_metric(hist, 'categorical_accuracy', 'val_categorical_accuracy',
            'Total Accuracy vs Total Validation Accuracy', 'Accuracy')

# %% [markdown]
# ### Saving the Model

# %% [markdown]
# The model achieved in the process is saved in a directory with current date and time along with the test loss and test accuracy. This allows retrieval of model that performed best for later predictions.

# %%
import datetime as dt

date_time_format = '%Y_%m_%d__%H_%M_%S' # the string date format.
current_date_time_dt = dt.datetime.now() # current Date and Time in a DateTime Object.
current_date_time_string = dt.datetime.strftime(
    current_date_time_dt, date_time_format) # convert the DateTime object to string according to the style mentioned in date_time_format string.

# naming system for model
model_file_name = f'ASL_Date_Time_{current_date_time_string}___Loss_{test_loss}___Accuracy_{test_accuracy}.h5'
model_file_path = main_path + 'model/'
os.makedirs(model_file_path, exist_ok=True)

# saving the model
model.save(model_file_path + f'{model_file_name}')
# Out:
# C:\Users\Maria\AppData\Roaming\Python\Python311\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# # Model Analysis

# %% [markdown]
# ### Confusion Matrix

# %% [markdown]
# **Finding Predicted Labels From Word Vectors**
#
# The encoded labels are loaded from the compressed npz `labels.npz` file. A `cosine_similarity` function is defined to calculate cosine similarity between two word vectors.
#
# `find_predicted_labels` calculates the predicted labels based on cosine similiarity with the actual label vectors. The label vector that produces the highest similarity score is chosen as the predicted label word.
#
# `find_actual_label` is used to create a list of the actual label words.
#
# Only 50 predicted and actual labels are chosen for better visualization. These are then printed to show the difference between the labels.

# %%
labels_dict = np.load(main_path + 'labels.npz', allow_pickle=True)

# %%
def cosine_similarity(v1, v2):
    return np.dot(v1, v2) / (np.linalg.norm(v1) * np.linalg.norm(v2))

# %%
def find_predicted_label(target_word_vector):
    most_similar_label = None
    max_similarity = -1  # initializing with a value less than possible similarity

    for label, word_vector in labels_dict.items():
        similarity = cosine_similarity(target_word_vector, word_vector)

        # updating if the current word vector is more similar
        if similarity > max_similarity:
            max_similarity = similarity
            most_similar_label = label

    if most_similar_label is not None:
        return most_similar_label
    else:
        return None

# %%
def find_actual_label(actual_word_vector):
    found_label = None
    for label, word_vector in labels_dict.items():
        if np.array_equal(word_vector, actual_word_vector):
            found_label = label
            break

    if found_label is not None:
        return found_label
    else:
        return None

# %%
predicted_labels = []
actual_labels = []

predicted_vectors = model.predict(X_test)

# for the first 50 elements
for predicted_vector, actual_vector in tqdm(zip(predicted_vectors[:50], Y_test[:50]), total=50, desc="Processing vectors"):

    predicted_label = find_predicted_label(predicted_vector)
    actual_label = find_actual_label(actual_vector)

    predicted_labels.append(predicted_label)
    actual_labels.append(actual_label)

# %%
print("Predicted Labels:")
print(predicted_labels)

print("Actual Labels:")
print(actual_labels)
# Out:
# Predicted Labels:
# ['book', 'book', 'man', 'book', 'book', 'book', 'white', 'book', 'book', 'man', 'book', 'book', 'man', 'book', 'all', 'book', 'book', 'white', 'book', 'book', 'book', 'book', 'man', 'book', 'man', 'book', 'book', 'book', 'book', 'book', 'book', 'like', 'book', 'book', 'book', 'white', 'book', 'man', 'book', 'book', 'man', 'white', 'man', 'man', 'book', 'book', 'book', 'book', 'all', 'book']
# Actual Labels:
# ['later', 'later', 'man', 'man', 'shirt', 'shirt', 'shirt', 'study', 'study', 'tall', 'tall', 'tall', 'white', 'white', 'before', 'before', 'before', 'before', 'chair', 'chair', 'chair', 'book', 'go', 'book', 'go', 'go', 'clothes', 'book', 'clothes', 'clothes', 'who', 'who', 'who', 'candy', 'candy', 'candy', 'cousin', 'book', 'cousin', 'cousin', 'deaf', 'deaf', 'deaf', 'fine', 'fine', 'fine', 'help', 'help', 'help', 'no']

# %% [markdown]
# **Plotting confusion matrix**
#
# Using the actual and predicted labels obtained, a confusion matrix is plotted to visualize the perfomance of the model.

# %%
conf_matrix = confusion_matrix(actual_labels, predicted_labels)

# Concatenating unique labels from actual and predicted
unique_labels = np.unique(np.concatenate([actual_labels, predicted_labels]))

# plotting the confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=unique_labels,
            yticklabels=unique_labels)
plt.title("Confusion Matrix - First 50 Samples")
plt.xlabel("Predicted Labels")
plt.ylabel("Actual Labels")
plt.show()

# %% [markdown]
# ### ROC and AUC

# %% [markdown]
# ROC and AUC is plotted to visualize the performance of model. `label_binarize` is used to binarize the actual and predicted labels. Each word/class is iterated to produce FPR and TPR to plot the ROC curve.
#
# ROC curves for the classes are plotted on the same graph for comparison and  the legends are used to display the ROC area for each word.

# %%
# binarizing the labels
classes = np.unique(actual_labels)
y_true = label_binarize(actual_labels, classes=classes)
y_score = label_binarize(predicted_labels, classes=classes)

# computing ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()

n_classes = len(classes)
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_true[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# plotting
plt.figure(figsize=(8, 6))
colors = cycle(['aqua', 'darkorange', 'lime', 'cornflowerblue', 'purple', 'gold', 'cyan', 'teal',
                'olive',  'blue', 'magenta', 'salmon', 'red', 'green', 'yellow', 'pink', 'brown', 'gray'])
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=2,
             label='ROC curve (area = {:.2f}) for class {}'.format(roc_auc[i], classes[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Multiclass ROC Curve')
plt.legend(loc="upper left", bbox_to_anchor=(1, 1))
plt.show()
